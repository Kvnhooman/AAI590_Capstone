# %% [markdown]
# # 06b — Mitigated Few-Shot Fine-Tuning
#
# learning rate was so low the model barely adapted, scoring *below* the naive Arm 1 (NB05)
# on both domains. This version gives the encoder real adaptation capacity while keeping the
# gradual-unfreeze + warmup cushion that protects against catastrophic forgetting.
#
# | Param | NB06 (v1) | NB06b (this) |
# |---|---|---|
# | `ENCODER_LEARNING_RATE` | 5e-6 | **2e-5** |
# | `FREEZE_EPOCHS` | 2 | **1** |
# | `UNFREEZE_EPOCHS` | 6 | **7** (total still 8) |
# | `HEAD_LEARNING_RATE` | 5e-5 | 5e-5 (unchanged) |
#
# Outputs are written to **`results/mitigated_retuned/`**, so NB06's original results in
# `results/mitigated/` are left intact for a side-by-side comparison. It still reads NB05's
# results for the three-way (zero-shot vs naive vs retuned) comparison.

# %% [markdown]
# # 06 — Mitigated Few-Shot Fine-Tuning
#
#
# | Dataset | Zero-shot boundary F1 (NB04) | Few-shot boundary F1 @50/100/200 (NB05) |
# |---|---|---|
# | WNUT-17 | **0.610** | 0.444 / 0.508 / 0.565 — *never recovers to the zero-shot level* |
# | SciERC  | 0.068 | 0.419 / 0.542 / 0.624 — clear win |
#
# On WNUT-17, naive fine-tuning on 50–200 sentences made entity-**boundary** detection worse
# than doing nothing, across all three seeds at every budget. That's the signature of
# **catastrophic forgetting**: the tiny target-domain fine-tuning signal overwrites the general
# "is this span an entity" knowledge the encoder picked up from the much larger CoNLL-2003
# training set, in exchange for learning WNUT-17's specific label types.
#
# **What this notebook changes, and why:**
#
# 1. **Lower, differential learning rates.** The encoder (already well-initialized) gets a much
#    smaller learning rate than the freshly-initialized classification head, instead of both
#    being updated at the same `2e-5`.
# 2. **Gradual unfreezing.** Phase 1 trains *only* the new classification head with the encoder
#    frozen, so the head isn't pushing huge, poorly-calibrated gradients back through the encoder
#    from step one. Phase 2 unfreezes the encoder and continues training both, at the lower
#    encoder learning rate.
# 3. **Warmup.** A linear warmup ratio is added (absent in Notebook 05), which further smooths
#    out the first, most destructive updates.
# 4. **Selection metric.** The best checkpoint is chosen using a **combined** metric
#    (`(typed_f1 + boundary_f1) / 2`) instead of `typed_f1` alone, so checkpoint selection can no
#    longer pick a model that traded away boundary detection for typed accuracy.

# %%
# !rm -rf /content/drive/MyDrive/AAI590/data/processed/results/mitigated_retuned
# !pip -q install "transformers==4.44.2" "datasets==2.19.2" "seqeval==1.2.2" "accelerate>=0.26.0" pandas matplotlib

import torch
print("GPU available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
else:
    print("WARNING: No GPU detected. In Colab, select Runtime > Change runtime type > GPU.")
# Out:
# GPU available: True
# GPU: Tesla T4

# %% [markdown]
# ## Quiet mode
#
# The cells below intentionally trigger a few harmless warnings from `transformers` and `huggingface_hub` (e.g. a note that no `HF_TOKEN` is set, or that a randomly-initialized head is expected -- classifier head here, or MLM head in Notebook 07). This cell silences those specific, known-benign warnings so the notebook output stays readable, without hiding real errors.

# %%
import os
import warnings
import logging

warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", message=".*HF_TOKEN.*")
warnings.filterwarnings("ignore", message=".*newly initialized.*")

os.environ["TOKENIZERS_PARALLELISM"] = "false"
os.environ["HF_HUB_DISABLE_SYMLINKS_WARNING"] = "1"

from transformers.utils import logging as hf_logging
hf_logging.set_verbosity_error()
logging.getLogger("huggingface_hub").setLevel(logging.ERROR)

# %% [markdown]
# ## Step 1 — Mount Drive and configure the experiment
#
# Same directory layout as Notebook 05. Results are written to a separate
# `results/mitigated` folder so Notebook 05's outputs are untouched.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=False)

import gc
import json
import random
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn

from datasets import load_from_disk
from seqeval.metrics import precision_score, recall_score, f1_score, classification_report
from transformers import (
    AutoConfig,
    AutoModelForTokenClassification,
    AutoTokenizer,
    DataCollatorForTokenClassification,
    EarlyStoppingCallback,
    Trainer,
    TrainingArguments,
    set_seed,
)

PROCESSED = Path("/content/drive/MyDrive/AAI590/data/processed")
TOKENIZED_DIR = PROCESSED / "tokenized"
LABELS_DIR = PROCESSED / "label_maps"
MODELS_DIR = PROCESSED / "models"
RESULTS_DIR = PROCESSED / "results"
BASELINE_DIR = MODELS_DIR / "baseline_conll2003"

NAIVE_FEWSHOT_RESULTS_DIR = RESULTS_DIR / "fewshot_v2"
MITIGATED_RESULTS_DIR = RESULTS_DIR / "mitigated_retuned"
MITIGATED_RESULTS_DIR.mkdir(parents=True, exist_ok=True)


TARGET_DATASETS = ["wnut17", "scierc"]
BUDGETS = [50, 100, 200]
SEEDS = [13, 42, 101]

# --- Mitigated fine-tuning settings ---
HEAD_LEARNING_RATE = 5e-5
ENCODER_LEARNING_RATE = 2e-5
WARMUP_RATIO = 0.1

FREEZE_EPOCHS = 1                 # Phase 1: encoder frozen, only the head trains -- constant across budgets
# Budget-scaled total epochs (freeze + unfreeze). NOTE: budget=50 uses fewer epochs
# here (10) than in NB05 (20) -- at 50 examples, 20 epochs through the phase-1/phase-2
# transition produced catastrophic divergence in 2 of 3 seeds on SciERC (validation
# combined_f1 ~0.04-0.06 vs ~0.43 for the surviving seed). Trading some of the
# low-budget training-length benefit for stability at this specific budget.
TOTAL_EPOCHS_BY_BUDGET = {50: 10, 100: 12, 200: 8}
# UNFREEZE_EPOCHS is now computed per-run inside run_mitigated_experiment as
# TOTAL_EPOCHS_BY_BUDGET[budget] - FREEZE_EPOCHS.
MAX_GRAD_NORM = 1.0                # explicit clipping during Phase 2 (encoder unfrozen)

TRAIN_BATCH_SIZE = 8
EVAL_BATCH_SIZE = 32
WEIGHT_DECAY = 0.01
EARLY_STOPPING_PATIENCE = 2       # applied during Phase 2 only

# Saving all 18 models can consume substantial Drive space.
SAVE_ALL_MODELS = False

required_paths = [TOKENIZED_DIR, LABELS_DIR, BASELINE_DIR]
for path in required_paths:
    if not path.exists():
        raise FileNotFoundError(
            f"Missing required path: {path}\n"
            "Run Notebooks 03 and 04 successfully before running Notebook 06."
        )

print("Processed directory:", PROCESSED)
print("Baseline model:", BASELINE_DIR)
print("Mitigated results directory:", MITIGATED_RESULTS_DIR)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Processed directory: /content/drive/MyDrive/AAI590/data/processed
# Baseline model: /content/drive/MyDrive/AAI590/data/processed/models/baseline_conll2003
# Mitigated results directory: /content/drive/MyDrive/AAI590/data/processed/results/mitigated_retuned

# %% [markdown]
# ## Step 2 — Load the baseline model and tokenizer
# Each target dataset
# still gets its own freshly-initialized classification head.

# %%
tokenizer = AutoTokenizer.from_pretrained(str(BASELINE_DIR), clean_up_tokenization_spaces=True)
baseline_model = AutoModelForTokenClassification.from_pretrained(str(BASELINE_DIR))

print("Baseline architecture:", baseline_model.config.model_type)
print("Baseline output labels:", baseline_model.config.num_labels)
print("Baseline encoder loaded successfully.")
# Out:
# Baseline architecture: bert
# Baseline output labels: 8
# Baseline encoder loaded successfully.

# %% [markdown]
# ## Step 3 — Helper functions
#
# Three additions:
#
# - `combined_f1` in the metrics dict, used for checkpoint selection.
# - `freeze_encoder` / `unfreeze_encoder` for the two training phases.
# - `build_two_group_optimizer`, which gives the head and the encoder different learning rates
#   (standard AdamW, but with separate parameter groups instead of one global `learning_rate`).

# %%
def load_label_map(dataset_name):
    path = LABELS_DIR / f"{dataset_name}_label_map.json"
    with open(path) as f:
        mapping = json.load(f)

    label2id = {str(k): int(v) for k, v in mapping["label2id"].items()}
    id2label = {int(k): str(v) for k, v in mapping["id2label"].items()}
    return label2id, id2label


def collapse_to_boundary(tag):
    '''Convert a typed BIO tag to O, B-ENT, or I-ENT.'''
    if tag == "O":
        return "O"
    if tag.startswith("B-"):
        return "B-ENT"
    if tag.startswith("I-"):
        return "I-ENT"
    raise ValueError(f"Unexpected BIO tag: {tag}")


def decode_predictions(eval_pred, id2label):
    '''Decode non-ignored labels and predictions into BIO tag sequences.'''
    predictions, labels = eval_pred
    predictions = np.argmax(predictions, axis=2)

    true_tags = []
    predicted_tags = []

    for pred_row, label_row in zip(predictions, labels):
        sentence_true = []
        sentence_pred = []

        for pred_id, label_id in zip(pred_row, label_row):
            if label_id == -100:
                continue

            sentence_true.append(id2label[int(label_id)])
            sentence_pred.append(id2label[int(pred_id)])

        true_tags.append(sentence_true)
        predicted_tags.append(sentence_pred)

    return true_tags, predicted_tags


def build_compute_metrics(id2label):
    '''Create a Trainer metric function for a target dataset's label map.

    Adds `combined_f1` = mean(typed_f1, boundary_f1) relative to Notebook 05, so
    checkpoint selection can't silently trade boundary detection for typed accuracy.
    '''
    def compute_metrics(eval_pred):
        true_tags, predicted_tags = decode_predictions(eval_pred, id2label)

        true_boundary = [
            [collapse_to_boundary(tag) for tag in sentence]
            for sentence in true_tags
        ]
        predicted_boundary = [
            [collapse_to_boundary(tag) for tag in sentence]
            for sentence in predicted_tags
        ]

        typed_f1 = f1_score(true_tags, predicted_tags)
        boundary_f1 = f1_score(true_boundary, predicted_boundary)

        return {
            "typed_precision": precision_score(true_tags, predicted_tags),
            "typed_recall": recall_score(true_tags, predicted_tags),
            "typed_f1": typed_f1,
            "boundary_precision": precision_score(true_boundary, predicted_boundary),
            "boundary_recall": recall_score(true_boundary, predicted_boundary),
            "boundary_f1": boundary_f1,
            "combined_f1": (typed_f1 + boundary_f1) / 2.0,
        }

    return compute_metrics


def load_target_datasets(dataset_name, budget, seed):
    fewshot_path = (
        TOKENIZED_DIR / "fewshot" / dataset_name /
        f"budget{budget}_seed{seed}"
    )
    validation_path = TOKENIZED_DIR / dataset_name / "validation"
    test_path = TOKENIZED_DIR / dataset_name / "test"

    for path in [fewshot_path, validation_path, test_path]:
        if not path.exists():
            raise FileNotFoundError(
                f"Missing tokenized dataset: {path}\n"
                "Re-run Notebook 03 to create all tokenized few-shot splits."
            )

    return (
        load_from_disk(str(fewshot_path)),
        load_from_disk(str(validation_path)),
        load_from_disk(str(test_path)),
    )


def create_target_model(dataset_name):
    '''Create a target-label model initialized with the CoNLL-trained encoder.'''
    label2id, id2label = load_label_map(dataset_name)

    config = AutoConfig.from_pretrained(
        "bert-base-cased",
        num_labels=len(id2label),
        label2id=label2id,
        id2label=id2label,
    )

    target_model = AutoModelForTokenClassification.from_pretrained(
        "bert-base-cased",
        config=config,
        ignore_mismatched_sizes=True,
    )

    # Transfer the source-domain representation learned in Notebook 04.
    target_model.base_model.load_state_dict(
        baseline_model.base_model.state_dict(),
        strict=True,
    )

    return target_model, label2id, id2label


def freeze_encoder(model):
    for param in model.base_model.parameters():
        param.requires_grad = False


def unfreeze_encoder(model):
    for param in model.base_model.parameters():
        param.requires_grad = True


def build_two_group_optimizer(model, encoder_lr, head_lr, weight_decay=0.01):
    '''AdamW with separate learning rates for the classification head vs. the encoder,
    preserving the usual no-weight-decay treatment for biases and LayerNorm weights.'''
    no_decay = ["bias", "LayerNorm.weight"]

    head_decay, head_no_decay = [], []
    encoder_decay, encoder_no_decay = [], []

    for name, param in model.named_parameters():
        if not param.requires_grad:
            continue
        is_head = name.startswith("classifier")
        is_no_decay = any(nd in name for nd in no_decay)

        if is_head:
            (head_no_decay if is_no_decay else head_decay).append(param)
        else:
            (encoder_no_decay if is_no_decay else encoder_decay).append(param)

    groups = [
        {"params": head_decay, "lr": head_lr, "weight_decay": weight_decay},
        {"params": head_no_decay, "lr": head_lr, "weight_decay": 0.0},
        {"params": encoder_decay, "lr": encoder_lr, "weight_decay": weight_decay},
        {"params": encoder_no_decay, "lr": encoder_lr, "weight_decay": 0.0},
    ]
    groups = [g for g in groups if len(g["params"]) > 0]
    return torch.optim.AdamW(groups)


def cleanup_memory(*objects):
    for obj in objects:
        try:
            del obj
        except Exception:
            pass
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

# %% [markdown]
# ## Step 4 — Sanity-check all required inputs
#
# Catches missing tokenized splits before starting a long run.

# %%
input_rows = []

for dataset_name in TARGET_DATASETS:
    label2id, id2label = load_label_map(dataset_name)

    for split in ["validation", "test"]:
        path = TOKENIZED_DIR / dataset_name / split
        input_rows.append({
            "dataset": dataset_name,
            "split": split,
            "budget": None,
            "seed": None,
            "exists": path.exists(),
            "path": str(path),
            "num_labels": len(id2label),
        })

    for budget in BUDGETS:
        for seed in SEEDS:
            path = (
                TOKENIZED_DIR / "fewshot" / dataset_name /
                f"budget{budget}_seed{seed}"
            )
            input_rows.append({
                "dataset": dataset_name,
                "split": "fewshot_train",
                "budget": budget,
                "seed": seed,
                "exists": path.exists(),
                "path": str(path),
                "num_labels": len(id2label),
            })

input_check_df = pd.DataFrame(input_rows)
display(input_check_df)

missing = input_check_df.loc[~input_check_df["exists"]]
if not missing.empty:
    raise FileNotFoundError(
        "Some required inputs are missing. Re-run Notebook 03.\n" +
        "\n".join(missing["path"].tolist())
    )

print("All required inputs are available.")
# Out:
#    dataset          split  budget   seed  exists  \
# 0   wnut17     validation     NaN    NaN    True
# 1   wnut17           test     NaN    NaN    True
# 2   wnut17  fewshot_train    50.0   13.0    True
# 3   wnut17  fewshot_train    50.0   42.0    True
# 4   wnut17  fewshot_train    50.0  101.0    True
# 5   wnut17  fewshot_train   100.0   13.0    True
# 6   wnut17  fewshot_train   100.0   42.0    True
# 7   wnut17  fewshot_train   100.0  101.0    True
# 8   wnut17  fewshot_train   200.0   13.0    True
# 9   wnut17  fewshot_train   200.0   42.0    True
# 10  wnut17  fewshot_train   200.0  101.0    True
# 11  scierc     validation     NaN    NaN    True
# 12  scierc           test     NaN    NaN    True
# 13  scierc  fewshot_train    50.0   13.0    True
# 14  scierc  fewshot_train    50.0   42.0    True
# 15  scierc  fewshot_train    50.0  101.0    True
# 16  scierc  fewshot_train   100.0   13.0    True
# 17  scierc  fewshot_train   100.0   42.0    True
# 18  scierc  fewshot_train   100.0  101.0    True
# 19  scierc  fewshot_train   200.0   13.0    True
# 20  scierc  fewshot_train   200.0   42.0    True
# 21  scierc  fewshot_train   200.0  101.0    True
#
#                                                  path  num_labels
# 0   /content/drive/MyDrive/AAI590/data/processed/t...          13
# 1   /content/drive/MyDrive/AAI590/data/processed/t...          13
# 2   /content/drive/MyDrive/AAI590/data/processed/t...          13
# 3   /content/drive/MyDrive/AAI590/data/processed/t...          13
# 4   /content/drive/MyDrive/AAI590/data/processed/t...          13
# 5   /content/drive/MyDrive/AAI590/data/processed/t...          13
# 6   /content/drive/MyDrive/AAI590/data/processed/t...          13
# 7   /content/drive/MyDrive/AAI590/data/processed/t...          13
# 8   /content/drive/MyDrive/AAI590/data/processed/t...          13
# 9   /content/drive/MyDrive/AAI590/data/processed/t...          13
# 10  /content/drive/MyDrive/AAI590/data/processed/t...          13
# 11  /content/drive/MyDrive/AAI590/data/processed/t...          13
# 12  /content/drive/MyDrive/AAI590/data/processed/t...          13
# 13  /content/drive/MyDrive/AAI590/data/processed/t...          13
# 14  /content/drive/MyDrive/AAI590/data/processed/t...          13
# 15  /content/drive/MyDrive/AAI590/data/processed/t...          13
# 16  /content/drive/MyDrive/AAI590/data/processed/t...          13
# 17  /content/drive/MyDrive/AAI590/data/processed/t...          13
# 18  /content/drive/MyDrive/AAI590/data/processed/t...          13
# 19  /content/drive/MyDrive/AAI590/data/processed/t...          13
# 20  /content/drive/MyDrive/AAI590/data/processed/t...          13
# 21  /content/drive/MyDrive/AAI590/data/processed/t...          13
# All required inputs are available.

# %% [markdown]
# ## Step 5 — Two-phase mitigated training
#
# **Phase 1 (head warm-start):** the encoder is frozen; only the new classification head trains,
# for `FREEZE_EPOCHS` epochs at `HEAD_LEARNING_RATE`. This gives the head a reasonable starting
# point before any gradient reaches the encoder, instead of the encoder absorbing large,
# poorly-calibrated gradients from a randomly-initialized head from step one.
#
# **Phase 2 (full fine-tune, differential LR):** the encoder is unfrozen. Both the head and the
# encoder train together for up to `UNFREEZE_EPOCHS` epochs, but through
# `build_two_group_optimizer` the encoder moves at `ENCODER_LEARNING_RATE` (much slower) while the
# head continues at `HEAD_LEARNING_RATE`. Warmup is applied, and early stopping now watches
# `combined_f1` rather than `typed_f1` alone. The checkpoint with the best `combined_f1` on the
# validation set is what gets evaluated on the held-out test set.

# %%
data_collator = DataCollatorForTokenClassification(tokenizer=tokenizer)


def run_mitigated_experiment(dataset_name, budget, seed):
    print("=" * 80)
    print(f"[MITIGATED] Dataset={dataset_name} | Budget={budget} | Seed={seed}")
    print("=" * 80)

    set_seed(seed)
    random.seed(seed)
    np.random.seed(seed)

    train_ds, validation_ds, test_ds = load_target_datasets(dataset_name, budget, seed)
    model, label2id, id2label = create_target_model(dataset_name)
    compute_metrics = build_compute_metrics(id2label)
    unfreeze_epochs = TOTAL_EPOCHS_BY_BUDGET[budget] - FREEZE_EPOCHS
    import time as _time
    _t0 = _time.time()

    run_name = f"{dataset_name}_budget{budget}_seed{seed}"
    checkpoint_dir = Path("/content/mitigated_checkpoints") / run_name

    # ---------------- Phase 1: freeze encoder, warm-start the head ----------------
    freeze_encoder(model)

    phase1_args = TrainingArguments(
        output_dir=str(checkpoint_dir / "phase1"),
        eval_strategy="no",
        save_strategy="no",
        logging_strategy="epoch",
        num_train_epochs=FREEZE_EPOCHS,
        per_device_train_batch_size=TRAIN_BATCH_SIZE,
        per_device_eval_batch_size=EVAL_BATCH_SIZE,
        weight_decay=WEIGHT_DECAY,
        warmup_ratio=WARMUP_RATIO,
        learning_rate=HEAD_LEARNING_RATE,  # only the head has grads, so this applies to it
        report_to="none",
        seed=seed,
        data_seed=seed,
    )

    phase1_trainer = Trainer(
        model=model,
        args=phase1_args,
        train_dataset=train_ds,
        eval_dataset=validation_ds,
        tokenizer=tokenizer,
        data_collator=data_collator,
        compute_metrics=compute_metrics,
    )
    phase1_trainer.train()

    # ---------------- Phase 2: unfreeze, differential LR, early stopping ----------------
    unfreeze_encoder(model)
    optimizer = build_two_group_optimizer(
        model,
        encoder_lr=ENCODER_LEARNING_RATE,
        head_lr=HEAD_LEARNING_RATE,
        weight_decay=WEIGHT_DECAY,
    )

    phase2_args = TrainingArguments(
        output_dir=str(checkpoint_dir / "phase2"),
        eval_strategy="epoch",
        save_strategy="epoch",
        logging_strategy="epoch",
        num_train_epochs=unfreeze_epochs,
        per_device_train_batch_size=TRAIN_BATCH_SIZE,
        per_device_eval_batch_size=EVAL_BATCH_SIZE,
        weight_decay=WEIGHT_DECAY,
        warmup_ratio=WARMUP_RATIO,
        learning_rate=ENCODER_LEARNING_RATE,
        load_best_model_at_end=True,
        metric_for_best_model="eval_combined_f1",
        greater_is_better=True,
        save_total_limit=1,
        report_to="none",
        seed=seed,
        data_seed=seed,
        max_grad_norm=MAX_GRAD_NORM,
    )

    phase2_trainer = Trainer(
        model=model,
        args=phase2_args,
        train_dataset=train_ds,
        eval_dataset=validation_ds,
        tokenizer=tokenizer,
        data_collator=data_collator,
        compute_metrics=compute_metrics,
        optimizers=(optimizer, None),  # None -> Trainer builds the default linear+warmup scheduler
        callbacks=[EarlyStoppingCallback(early_stopping_patience=EARLY_STOPPING_PATIENCE)],
    )
    train_output = phase2_trainer.train()
    train_seconds = _time.time() - _t0

    validation_metrics = phase2_trainer.evaluate(validation_ds)
    test_metrics = phase2_trainer.evaluate(test_ds, metric_key_prefix="test")


    _preds, _labels, _ = phase2_trainer.predict(test_ds)
    _preds = np.argmax(_preds, axis=2)
    _tt, _pp = [], []
    for _pr, _lr in zip(_preds, _labels):
        _st, _sp = [], []
        for _p, _l in zip(_pr, _lr):
            if _l == -100:
                continue
            _st.append(id2label[int(_l)]); _sp.append(id2label[int(_p)])
        _tt.append(_st); _pp.append(_sp)
    _rep = classification_report(_tt, _pp, output_dict=True, zero_division=0)
    per_type = {k: {"precision": float(v["precision"]), "recall": float(v["recall"]),
                    "f1": float(v["f1-score"]), "support": int(v["support"])}
                for k, v in _rep.items()
                if k not in ("micro avg", "macro avg", "weighted avg")}

    if SAVE_ALL_MODELS:
        model_output_dir = (
            MODELS_DIR / "mitigated" / dataset_name /
            f"budget{budget}_seed{seed}"
        )
        model_output_dir.mkdir(parents=True, exist_ok=True)
        phase2_trainer.save_model(str(model_output_dir))
        tokenizer.save_pretrained(str(model_output_dir))
        saved_model_path = str(model_output_dir)
    else:
        saved_model_path = None

    result = {
        "dataset": dataset_name,
        "budget": budget,
        "seed": seed,
        "num_train_sentences": len(train_ds),
        "num_epochs": TOTAL_EPOCHS_BY_BUDGET[budget],
        "best_checkpoint": phase2_trainer.state.best_model_checkpoint,
        "best_validation_metric": phase2_trainer.state.best_metric,
        "training_loss": train_output.training_loss,
        "validation_typed_f1": validation_metrics.get("eval_typed_f1"),
        "validation_boundary_f1": validation_metrics.get("eval_boundary_f1"),
        "validation_combined_f1": validation_metrics.get("eval_combined_f1"),
        "test_typed_precision": test_metrics.get("test_typed_precision"),
        "test_typed_recall": test_metrics.get("test_typed_recall"),
        "test_typed_f1": test_metrics.get("test_typed_f1"),
        "test_boundary_precision": test_metrics.get("test_boundary_precision"),
        "test_boundary_recall": test_metrics.get("test_boundary_recall"),
        "test_boundary_f1": test_metrics.get("test_boundary_f1"),
        "test_combined_f1": test_metrics.get("test_combined_f1"),
        "train_seconds": round(train_seconds, 1),
        "per_type": json.dumps(per_type),
        "saved_model_path": saved_model_path,
    }

    print("\nTest results (mitigated):")
    print(f"  Typed F1:    {result['test_typed_f1']:.4f}")
    print(f"  Boundary F1: {result['test_boundary_f1']:.4f}")

    cleanup_memory(phase1_trainer, phase2_trainer, optimizer, model, train_ds, validation_ds, test_ds)
    return result

# %% [markdown]
# ## Step 6 — Run the complete experiment grid
#
# Same 18 runs as Notebook 05 (2 datasets × 3 budgets × 3 seeds), so the two result sets line up
# row for row.

# %%
RESULTS_CSV = MITIGATED_RESULTS_DIR / "mitigated_results.csv"
RESULTS_JSON = MITIGATED_RESULTS_DIR / "mitigated_results.json"

if RESULTS_CSV.exists():
    results_df = pd.read_csv(RESULTS_CSV)
    completed = {
        (row.dataset, int(row.budget), int(row.seed))
        for row in results_df.itertuples()
    }
    all_results = results_df.to_dict("records")
    print(f"Resuming from {len(all_results)} completed runs.")
else:
    completed = set()
    all_results = []

for dataset_name in TARGET_DATASETS:
    for budget in BUDGETS:
        for seed in SEEDS:
            key = (dataset_name, budget, seed)

            if key in completed:
                print("Skipping completed run:", key)
                continue

            result = run_mitigated_experiment(dataset_name, budget, seed)
            all_results.append(result)
            completed.add(key)

            results_df = pd.DataFrame(all_results).sort_values(["dataset", "budget", "seed"])
            results_df.to_csv(RESULTS_CSV, index=False)

            with open(RESULTS_JSON, "w") as f:
                json.dump(
                    results_df.replace({np.nan: None}).to_dict("records"),
                    f,
                    indent=2,
                    default=str,
                )

            print("Saved progress to:", RESULTS_CSV)

results_df = pd.DataFrame(all_results).sort_values(
    ["dataset", "budget", "seed"]
).reset_index(drop=True)

display(results_df)
# Out:
# ================================================================================
# [MITIGATED] Dataset=wnut17 | Budget=50 | Seed=13
# ================================================================================
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# {'loss': 3.3408, 'grad_norm': 17.710323333740234, 'learning_rate': 0.0, 'epoch': 1.0}
# {'train_runtime': 1.1397, 'train_samples_per_second': 43.871, 'train_steps_per_second': 6.142, 'train_loss': 3.3407794407435825, 'epoch': 1.0}
# {'loss': 2.8495, 'grad_norm': 22.15484619140625, 'learning_rate': 5e-05, 'epoch': 1.0}
# {'eval_loss': 1.5838055610656738, 'eval_typed_precision': 0.019550342130987292, 'eval_typed_recall': 0.023923444976076555, 'eval_typed_f1': 0.021516944593867673, 'eval_boundary_precision': 0.42288049029622066, 'eval_boundary_recall': 0.49521531100478466, 'eval_boundary_f1': 0.456198347107438, 'eval_combined_f1': 0.23885764585065283, 'eval_runtime': 2.8598, 'eval_samples_per_second': 352.826, 'eval_steps_per_second': 11.19, 'epoch': 1.0}
# {'loss': 0.8504, 'grad_norm': 3.538503646850586, 'learning_rate': 4.375e-05, 'epoch': 2.0}
# {'eval_loss': 0.3813779652118683, 'eval_typed_precision': 0.35714285714285715, 'eval_typed_recall': 0.05980861244019139, 'eval_typed_f1': 0.10245901639344263, 'eval_boundary_precision': 0.5970149253731343, 'eval_boundary_recall': 0.09569377990430622, 'eval_boundary_f1': 0.16494845360824742, 'eval_combined_f1': 0.13370373500084504, 'eval_runtime': 3.5102, 'eval_samples_per_second': 287.452, 'eval_steps_per_second': 9.116, 'epoch': 2.0}
# {'loss': 0.3961, 'grad_norm': 2.543444871902466, 'learning_rate': 3.7500000000000003e-05, 'epoch': 3.0}
# {'eval_loss': 0.34056219458580017, 'eval_typed_precision': 0.5640326975476839, 'eval_typed_recall': 0.24760765550239233, 'eval_typed_f1': 0.34413965087281795, 'eval_boundary_precision': 0.670299727520436, 'eval_boundary_recall': 0.2942583732057416, 'eval_boundary_f1': 0.4089775561097257, 'eval_combined_f1': 0.3765586034912718, 'eval_runtime': 2.9154, 'eval_samples_per_second': 346.09, 'eval_steps_per_second': 10.976, 'epoch': 3.0}
# {'loss': 0.2855, 'grad_norm': 1.0329296588897705, 'learning_rate': 3.125e-05, 'epoch': 4.0}
# {'eval_loss': 0.3205551505088806, 'eval_typed_precision': 0.4549618320610687, 'eval_typed_recall': 0.35645933014354064, 'eval_typed_f1': 0.3997317236753857, 'eval_boundary_precision': 0.5694656488549619, 'eval_boundary_recall': 0.4461722488038278, 'eval_boundary_f1': 0.500335345405768, 'eval_combined_f1': 0.4500335345405768, 'eval_runtime': 2.9879, 'eval_samples_per_second': 337.69, 'eval_steps_per_second': 10.71, 'epoch': 4.0}
# {'loss': 0.2443, 'grad_norm': 2.9246437549591064, 'learning_rate': 2.5e-05, 'epoch': 5.0}
# {'eval_loss': 0.3181743323802948, 'eval_typed_precision': 0.4657534246575342, 'eval_typed_recall': 0.3660287081339713, 'eval_typed_f1': 0.40991292699263226, 'eval_boundary_precision': 0.573170731707317, 'eval_boundary_recall': 0.44976076555023925, 'eval_boundary_f1': 0.5040214477211796, 'eval_combined_f1': 0.45696718735690595, 'eval_runtime': 3.0122, 'eval_samples_per_second': 334.971, 'eval_steps_per_second': 10.623, 'epoch': 5.0}
# {'loss': 0.2013, 'grad_norm': 3.73130464553833, 'learning_rate': 1.8750000000000002e-05, 'epoch': 6.0}
# {'eval_loss': 0.3225485384464264, 'eval_typed_precision': 0.4840764331210191, 'eval_typed_recall': 0.36363636363636365, 'eval_typed_f1': 0.41530054644808745, 'eval_boundary_precision': 0.5904, 'eval_boundary_recall': 0.44138755980861244, 'eval_boundary_f1': 0.5051334702258728, 'eval_combined_f1': 0.46021700833698015, 'eval_runtime': 4.1346, 'eval_samples_per_second': 244.036, 'eval_steps_per_second': 7.739, 'epoch': 6.0}
# {'loss': 0.1785, 'grad_norm': 2.339510917663574, 'learning_rate': 1.25e-05, 'epoch': 7.0}
# {'eval_loss': 0.3229883313179016, 'eval_typed_precision': 0.48073959938366717, 'eval_typed_recall': 0.37320574162679426, 'eval_typed_f1': 0.42020202020202024, 'eval_boundary_precision': 0.5972006220839814, 'eval_boundary_recall': 0.45933014354066987, 'eval_boundary_f1': 0.5192697768762679, 'eval_combined_f1': 0.46973589853914405, 'eval_runtime': 3.0788, 'eval_samples_per_second': 327.721, 'eval_steps_per_second': 10.394, 'epoch': 7.0}
# {'loss': 0.1588, 'grad_norm': 0.880580484867096, 'learning_rate': 6.25e-06, 'epoch': 8.0}
# {'eval_loss': 0.32259777188301086, 'eval_typed_precision': 0.4716417910447761, 'eval_typed_recall': 0.37799043062200954, 'eval_typed_f1': 0.41965471447543157, 'eval_boundary_precision': 0.5942684766214178, 'eval_boundary_recall': 0.47129186602870815, 'eval_boundary_f1': 0.5256837891927952, 'eval_combined_f1': 0.4726692518341134, 'eval_runtime': 3.1146, 'eval_samples_per_second': 323.955, 'eval_steps_per_second': 10.274, 'epoch': 8.0}
# {'loss': 0.1589, 'grad_norm': 1.10153067111969, 'learning_rate': 0.0, 'epoch': 9.0}
# {'eval_loss': 0.3227469027042389, 'eval_typed_precision': 0.47234678624813153, 'eval_typed_recall': 0.37799043062200954, 'eval_typed_f1': 0.41993355481727573, 'eval_boundary_precision': 0.5942684766214178, 'eval_boundary_recall': 0.47129186602870815, 'eval_boundary_f1': 0.5256837891927952, 'eval_combined_f1': 0.4728086720050355, 'eval_runtime': 3.4334, 'eval_samples_per_second': 293.877, 'eval_steps_per_second': 9.32, 'epoch': 9.0}
# {'train_runtime': 144.3324, 'train_samples_per_second': 3.118, 'train_steps_per_second': 0.436, 'train_loss': 0.5914790195132059, 'epoch': 9.0}
# {'eval_loss': 0.3227469027042389, 'eval_typed_precision': 0.47234678624813153, 'eval_typed_recall': 0.37799043062200954, 'eval_typed_f1': 0.41993355481727573, 'eval_boundary_precision': 0.5942684766214178, 'eval_boundary_recall': 0.47129186602870815, 'eval_boundary_f1': 0.5256837891927952, 'eval_combined_f1': 0.4728086720050355, 'eval_runtime': 3.5084, 'eval_samples_per_second': 287.597, 'eval_steps_per_second': 9.121, 'epoch': 9.0}
# {'test_loss': 0.3273654580116272, 'test_typed_precision': 0.36553238199780463, 'test_typed_recall': 0.3086190917516219, 'test_typed_f1': 0.33467336683417087, 'test_boundary_precision': 0.5176600441501104, 'test_boundary_recall': 0.43466172381835033, 'test_boundary_f1': 0.472544080604534, 'test_combined_f1': 0.4036087237193524, 'test_runtime': 6.9262, 'test_samples_per_second': 185.816, 'test_steps_per_second': 5.92, 'epoch': 9.0}
#
# Test results (mitigated):
#   Typed F1:    0.3347
#   Boundary F1: 0.4725
# Saved progress to: /content/drive/MyDrive/AAI590/data/processed/results/mitigated_retuned/mitigated_results.csv
# ================================================================================
# [MITIGATED] Dataset=wnut17 | Budget=50 | Seed=42
# ================================================================================
# {'loss': 2.112, 'grad_norm': 14.320965766906738, 'learning_rate': 0.0, 'epoch': 1.0}
# {'train_runtime': 0.2862, 'train_samples_per_second': 174.674, 'train_steps_per_second': 24.454, 'train_loss': 2.1120477403913225, 'epoch': 1.0}
# {'loss': 1.7224, 'grad_norm': 13.651491165161133, 'learning_rate': 5e-05, 'epoch': 1.0}
# {'eval_loss': 0.7837199568748474, 'eval_typed_precision': 0.2905982905982906, 'eval_typed_recall': 0.16267942583732056, 'eval_typed_f1': 0.2085889570552147, 'eval_boundary_precision': 0.5655021834061136, 'eval_boundary_recall': 0.30980861244019137, 'eval_boundary_f1': 0.40030911901081917, 'eval_combined_f1': 0.3044490380330169, 'eval_runtime': 3.4222, 'eval_samples_per_second': 294.839, 'eval_steps_per_second': 9.351, 'epoch': 1.0}
# {'loss': 0.4665, 'grad_norm': 3.3316502571105957, 'learning_rate': 4.375e-05, 'epoch': 2.0}
# {'eval_loss': 0.3570783734321594, 'eval_typed_precision': 0.3870967741935484, 'eval_typed_recall': 0.0430622009569378, 'eval_typed_f1': 0.07750269106566202, 'eval_boundary_precision': 0.45161290322580644, 'eval_boundary_recall': 0.050239234449760764, 'eval_boundary_f1': 0.09041980624327232, 'eval_combined_f1': 0.08396124865446716, 'eval_runtime': 3.4424, 'eval_samples_per_second': 293.111, 'eval_steps_per_second': 9.296, 'epoch': 2.0}
# {'loss': 0.2511, 'grad_norm': 1.1029226779937744, 'learning_rate': 3.7500000000000003e-05, 'epoch': 3.0}
# {'eval_loss': 0.3130030632019043, 'eval_typed_precision': 0.44534412955465585, 'eval_typed_recall': 0.2631578947368421, 'eval_typed_f1': 0.3308270676691729, 'eval_boundary_precision': 0.539553752535497, 'eval_boundary_recall': 0.3181818181818182, 'eval_boundary_f1': 0.400300978179082, 'eval_combined_f1': 0.3655640229241275, 'eval_runtime': 3.6682, 'eval_samples_per_second': 275.07, 'eval_steps_per_second': 8.724, 'epoch': 3.0}
# {'loss': 0.1862, 'grad_norm': 1.81173837184906, 'learning_rate': 3.125e-05, 'epoch': 4.0}
# {'eval_loss': 0.2970011830329895, 'eval_typed_precision': 0.3991989319092123, 'eval_typed_recall': 0.3576555023923445, 'eval_typed_f1': 0.3772870662460568, 'eval_boundary_precision': 0.4906166219839142, 'eval_boundary_recall': 0.43779904306220097, 'eval_boundary_f1': 0.46270543615676357, 'eval_combined_f1': 0.41999625120141015, 'eval_runtime': 3.5384, 'eval_samples_per_second': 285.155, 'eval_steps_per_second': 9.044, 'epoch': 4.0}
# {'loss': 0.1398, 'grad_norm': 1.3907219171524048, 'learning_rate': 2.5e-05, 'epoch': 5.0}
# {'eval_loss': 0.3061324954032898, 'eval_typed_precision': 0.416793893129771, 'eval_typed_recall': 0.326555023923445, 'eval_typed_f1': 0.3661971830985916, 'eval_boundary_precision': 0.5254237288135594, 'eval_boundary_recall': 0.40789473684210525, 'eval_boundary_f1': 0.4592592592592593, 'eval_combined_f1': 0.4127282211789255, 'eval_runtime': 3.6534, 'eval_samples_per_second': 276.184, 'eval_steps_per_second': 8.759, 'epoch': 5.0}
# {'loss': 0.1318, 'grad_norm': 2.408001184463501, 'learning_rate': 1.8750000000000002e-05, 'epoch': 6.0}
# {'eval_loss': 0.31112968921661377, 'eval_typed_precision': 0.42260061919504643, 'eval_typed_recall': 0.326555023923445, 'eval_typed_f1': 0.368421052631579, 'eval_boundary_precision': 0.5328125, 'eval_boundary_recall': 0.40789473684210525, 'eval_boundary_f1': 0.462059620596206, 'eval_combined_f1': 0.4152403366138925, 'eval_runtime': 3.7337, 'eval_samples_per_second': 270.242, 'eval_steps_per_second': 8.571, 'epoch': 6.0}
# {'train_runtime': 89.8698, 'train_samples_per_second': 5.007, 'train_steps_per_second': 0.701, 'train_loss': 0.48294719344093684, 'epoch': 6.0}
# {'eval_loss': 0.2970011830329895, 'eval_typed_precision': 0.3991989319092123, 'eval_typed_recall': 0.3576555023923445, 'eval_typed_f1': 0.3772870662460568, 'eval_boundary_precision': 0.4906166219839142, 'eval_boundary_recall': 0.43779904306220097, 'eval_boundary_f1': 0.46270543615676357, 'eval_combined_f1': 0.41999625120141015, 'eval_runtime': 3.6691, 'eval_samples_per_second': 274.998, 'eval_steps_per_second': 8.721, 'epoch': 6.0}
# {'test_loss': 0.31042787432670593, 'test_typed_precision': 0.29602510460251047, 'test_typed_recall': 0.2622798887859129, 'test_typed_f1': 0.2781326781326781, 'test_boundary_precision': 0.4586387434554974, 'test_boundary_recall': 0.40593141797961074, 'test_boundary_f1': 0.4306784660766962, 'test_combined_f1': 0.35440557210468715, 'test_runtime': 7.387, 'test_samples_per_second': 174.225, 'test_steps_per_second': 5.55, 'epoch': 6.0}
#
# Test results (mitigated):
#   Typed F1:    0.2781
#   Boundary F1: 0.4307
# Saved progress to: /content/drive/MyDrive/AAI590/data/processed/results/mitigated_retuned/mitigated_results.csv
# ================================================================================
# [MITIGATED] Dataset=wnut17 | Budget=50 | Seed=101
# ================================================================================
# {'loss': 2.634, 'grad_norm': 14.62747573852539, 'learning_rate': 0.0, 'epoch': 1.0}
# {'train_runtime': 0.2877, 'train_samples_per_second': 173.762, 'train_steps_per_second': 24.327, 'train_loss': 2.6340010506766185, 'epoch': 1.0}
# {'loss': 2.2187, 'grad_norm': 16.443729400634766, 'learning_rate': 5e-05, 'epoch': 1.0}
# {'eval_loss': 1.0813747644424438, 'eval_typed_precision': 0.3410071942446043, 'eval_typed_recall': 0.2834928229665072, 'eval_typed_f1': 0.30960156760287394, 'eval_boundary_precision': 0.511177347242921, 'eval_boundary_recall': 0.4102870813397129, 'eval_boundary_f1': 0.4552090245520902, 'eval_combined_f1': 0.3824052960774821, 'eval_runtime': 3.4614, 'eval_samples_per_second': 291.499, 'eval_steps_per_second': 9.245, 'epoch': 1.0}
# {'loss': 0.6553, 'grad_norm': 3.223675489425659, 'learning_rate': 4.375e-05, 'epoch': 2.0}
# {'eval_loss': 0.336725652217865, 'eval_typed_precision': 0.5, 'eval_typed_recall': 0.14952153110047847, 'eval_typed_f1': 0.2302025782688766, 'eval_boundary_precision': 0.564, 'eval_boundary_recall': 0.1686602870813397, 'eval_boundary_f1': 0.25966850828729277, 'eval_combined_f1': 0.2449355432780847, 'eval_runtime': 3.3112, 'eval_samples_per_second': 304.722, 'eval_steps_per_second': 9.664, 'epoch': 2.0}
# {'loss': 0.3432, 'grad_norm': 2.122211456298828, 'learning_rate': 3.7500000000000003e-05, 'epoch': 3.0}
# {'eval_loss': 0.3075590133666992, 'eval_typed_precision': 0.4432, 'eval_typed_recall': 0.33133971291866027, 'eval_typed_f1': 0.37919233401779606, 'eval_boundary_precision': 0.5329052969502408, 'eval_boundary_recall': 0.39712918660287083, 'eval_boundary_f1': 0.45510623714873205, 'eval_combined_f1': 0.41714928558326403, 'eval_runtime': 3.605, 'eval_samples_per_second': 279.89, 'eval_steps_per_second': 8.877, 'epoch': 3.0}
# {'loss': 0.266, 'grad_norm': 2.9648327827453613, 'learning_rate': 3.125e-05, 'epoch': 4.0}
# {'eval_loss': 0.30591633915901184, 'eval_typed_precision': 0.4030054644808743, 'eval_typed_recall': 0.35287081339712917, 'eval_typed_f1': 0.3762755102040816, 'eval_boundary_precision': 0.49657064471879286, 'eval_boundary_recall': 0.43301435406698563, 'eval_boundary_f1': 0.46261980830670923, 'eval_combined_f1': 0.4194476592553954, 'eval_runtime': 3.4452, 'eval_samples_per_second': 292.87, 'eval_steps_per_second': 9.288, 'epoch': 4.0}
# {'loss': 0.2279, 'grad_norm': 1.529229998588562, 'learning_rate': 2.5e-05, 'epoch': 5.0}
# {'eval_loss': 0.31508055329322815, 'eval_typed_precision': 0.40559440559440557, 'eval_typed_recall': 0.34688995215311, 'eval_typed_f1': 0.37395228884590587, 'eval_boundary_precision': 0.5007032348804501, 'eval_boundary_recall': 0.4258373205741627, 'eval_boundary_f1': 0.460245636716225, 'eval_combined_f1': 0.4170989627810654, 'eval_runtime': 3.512, 'eval_samples_per_second': 287.298, 'eval_steps_per_second': 9.112, 'epoch': 5.0}
# {'loss': 0.178, 'grad_norm': 1.7938109636306763, 'learning_rate': 1.8750000000000002e-05, 'epoch': 6.0}
# {'eval_loss': 0.3135015070438385, 'eval_typed_precision': 0.3970976253298153, 'eval_typed_recall': 0.36004784688995217, 'eval_typed_f1': 0.3776662484316186, 'eval_boundary_precision': 0.4986737400530504, 'eval_boundary_recall': 0.44976076555023925, 'eval_boundary_f1': 0.4729559748427673, 'eval_combined_f1': 0.42531111163719293, 'eval_runtime': 3.5228, 'eval_samples_per_second': 286.418, 'eval_steps_per_second': 9.084, 'epoch': 6.0}
# {'loss': 0.1711, 'grad_norm': 1.239161729812622, 'learning_rate': 1.25e-05, 'epoch': 7.0}
# {'eval_loss': 0.31272080540657043, 'eval_typed_precision': 0.38923654568210264, 'eval_typed_recall': 0.37200956937799046, 'eval_typed_f1': 0.3804281345565749, 'eval_boundary_precision': 0.48675914249684743, 'eval_boundary_recall': 0.46172248803827753, 'eval_boundary_f1': 0.4739103744628607, 'eval_combined_f1': 0.4271692545097178, 'eval_runtime': 3.5604, 'eval_samples_per_second': 283.394, 'eval_steps_per_second': 8.988, 'epoch': 7.0}
# {'loss': 0.1472, 'grad_norm': 0.7616353034973145, 'learning_rate': 6.25e-06, 'epoch': 8.0}
# {'eval_loss': 0.31308066844940186, 'eval_typed_precision': 0.3888888888888889, 'eval_typed_recall': 0.37679425837320574, 'eval_typed_f1': 0.3827460510328068, 'eval_boundary_precision': 0.48813982521847693, 'eval_boundary_recall': 0.4677033492822967, 'eval_boundary_f1': 0.4777031154551008, 'eval_combined_f1': 0.4302245832439538, 'eval_runtime': 3.5927, 'eval_samples_per_second': 280.844, 'eval_steps_per_second': 8.907, 'epoch': 8.0}
# {'loss': 0.1395, 'grad_norm': 0.7180494070053101, 'learning_rate': 0.0, 'epoch': 9.0}
# {'eval_loss': 0.3124150037765503, 'eval_typed_precision': 0.3889570552147239, 'eval_typed_recall': 0.3791866028708134, 'eval_typed_f1': 0.3840096910963053, 'eval_boundary_precision': 0.48698884758364314, 'eval_boundary_recall': 0.4700956937799043, 'eval_boundary_f1': 0.4783931832014608, 'eval_combined_f1': 0.43120143714888304, 'eval_runtime': 3.4832, 'eval_samples_per_second': 289.675, 'eval_steps_per_second': 9.187, 'epoch': 9.0}
# {'train_runtime': 130.5778, 'train_samples_per_second': 3.446, 'train_steps_per_second': 0.482, 'train_loss': 0.48298217001415433, 'epoch': 9.0}
# {'eval_loss': 0.3124150037765503, 'eval_typed_precision': 0.3889570552147239, 'eval_typed_recall': 0.3791866028708134, 'eval_typed_f1': 0.3840096910963053, 'eval_boundary_precision': 0.48698884758364314, 'eval_boundary_recall': 0.4700956937799043, 'eval_boundary_f1': 0.4783931832014608, 'eval_combined_f1': 0.43120143714888304, 'eval_runtime': 3.5312, 'eval_samples_per_second': 285.741, 'eval_steps_per_second': 9.062, 'epoch': 9.0}
# {'test_loss': 0.31934139132499695, 'test_typed_precision': 0.2924187725631769, 'test_typed_recall': 0.3002780352177943, 'test_typed_f1': 0.29629629629629634, 'test_boundary_precision': 0.43727272727272726, 'test_boundary_recall': 0.4457831325301205, 'test_boundary_f1': 0.44148692060578243, 'test_combined_f1': 0.3688916084510394, 'test_runtime': 7.6498, 'test_samples_per_second': 168.239, 'test_steps_per_second': 5.36, 'epoch': 9.0}
#
# Test results (mitigated):
#   Typed F1:    0.2963
#   Boundary F1: 0.4415
# Saved progress to: /content/drive/MyDrive/AAI590/data/processed/results/mitigated_retuned/mitigated_results.csv
# ================================================================================
# [MITIGATED] Dataset=wnut17 | Budget=100 | Seed=13
# ================================================================================
# {'loss': 3.2431, 'grad_norm': 15.493247032165527, 'learning_rate': 0.0, 'epoch': 1.0}
# {'train_runtime': 0.4906, 'train_samples_per_second': 203.831, 'train_steps_per_second': 26.498, 'train_loss': 3.2431150583120494, 'epoch': 1.0}
# {'loss': 2.3574, 'grad_norm': 10.814749717712402, 'learning_rate': 4.3333333333333334e-05, 'epoch': 1.0}
# {'eval_loss': 0.7120968699455261, 'eval_typed_precision': 0.02333931777378815, 'eval_typed_recall': 0.01555023923444976, 'eval_typed_f1': 0.01866475233309404, 'eval_boundary_precision': 0.5479704797047971, 'eval_boundary_recall': 0.35526315789473684, 'eval_boundary_f1': 0.4310595065312046, 'eval_combined_f1': 0.22486212943214934, 'eval_runtime': 3.5142, 'eval_samples_per_second': 287.118, 'eval_steps_per_second': 9.106, 'epoch': 1.0}
# {'loss': 0.43, 'grad_norm': 2.827512264251709, 'learning_rate': 4.5703125e-05, 'epoch': 2.0}
# {'eval_loss': 0.3317202031612396, 'eval_typed_precision': 0.3804347826086957, 'eval_typed_recall': 0.3349282296650718, 'eval_typed_f1': 0.356234096692112, 'eval_boundary_precision': 0.5191780821917809, 'eval_boundary_recall': 0.4533492822966507, 'eval_boundary_f1': 0.48403575989782893, 'eval_combined_f1': 0.42013492829497046, 'eval_runtime': 3.3562, 'eval_samples_per_second': 300.636, 'eval_steps_per_second': 9.535, 'epoch': 2.0}
# {'loss': 0.2897, 'grad_norm': 7.870808124542236, 'learning_rate': 4.0625000000000005e-05, 'epoch': 3.0}
# {'eval_loss': 0.3065244257450104, 'eval_typed_precision': 0.40963855421686746, 'eval_typed_recall': 0.3660287081339713, 'eval_typed_f1': 0.38660770688566015, 'eval_boundary_precision': 0.5053763440860215, 'eval_boundary_recall': 0.44976076555023925, 'eval_boundary_f1': 0.47594936708860763, 'eval_combined_f1': 0.4312785369871339, 'eval_runtime': 3.3788, 'eval_samples_per_second': 298.624, 'eval_steps_per_second': 9.471, 'epoch': 3.0}
# {'loss': 0.2102, 'grad_norm': 1.3350865840911865, 'learning_rate': 3.5546875e-05, 'epoch': 4.0}
# {'eval_loss': 0.31622111797332764, 'eval_typed_precision': 0.4587706146926537, 'eval_typed_recall': 0.3660287081339713, 'eval_typed_f1': 0.40718562874251496, 'eval_boundary_precision': 0.56797583081571, 'eval_boundary_recall': 0.44976076555023925, 'eval_boundary_f1': 0.5020026702269693, 'eval_combined_f1': 0.45459414948474214, 'eval_runtime': 3.552, 'eval_samples_per_second': 284.066, 'eval_steps_per_second': 9.009, 'epoch': 4.0}
# {'loss': 0.1651, 'grad_norm': 1.8724799156188965, 'learning_rate': 3.0468750000000002e-05, 'epoch': 5.0}
# {'eval_loss': 0.29853716492652893, 'eval_typed_precision': 0.4697173620457604, 'eval_typed_recall': 0.41746411483253587, 'eval_typed_f1': 0.4420519316022799, 'eval_boundary_precision': 0.6086956521739131, 'eval_boundary_recall': 0.5358851674641149, 'eval_boundary_f1': 0.5699745547073791, 'eval_combined_f1': 0.5060132431548295, 'eval_runtime': 3.6878, 'eval_samples_per_second': 273.606, 'eval_steps_per_second': 8.677, 'epoch': 5.0}
# {'loss': 0.1213, 'grad_norm': 2.473381757736206, 'learning_rate': 2.5390625000000002e-05, 'epoch': 6.0}
# {'eval_loss': 0.30878642201423645, 'eval_typed_precision': 0.4895977808599168, 'eval_typed_recall': 0.4222488038277512, 'eval_typed_f1': 0.45343609505459215, 'eval_boundary_precision': 0.6153846153846154, 'eval_boundary_recall': 0.5263157894736842, 'eval_boundary_f1': 0.5673758865248227, 'eval_combined_f1': 0.5104059907897074, 'eval_runtime': 3.7415, 'eval_samples_per_second': 269.675, 'eval_steps_per_second': 8.553, 'epoch': 6.0}
# {'loss': 0.1, 'grad_norm': 1.145334005355835, 'learning_rate': 2.0312500000000002e-05, 'epoch': 7.0}
# {'eval_loss': 0.3079485595226288, 'eval_typed_precision': 0.49239280774550487, 'eval_typed_recall': 0.4258373205741627, 'eval_typed_f1': 0.4567030147530468, 'eval_boundary_precision': 0.6518105849582173, 'eval_boundary_recall': 0.5598086124401914, 'eval_boundary_f1': 0.6023166023166023, 'eval_combined_f1': 0.5295098085348245, 'eval_runtime': 3.7412, 'eval_samples_per_second': 269.703, 'eval_steps_per_second': 8.554, 'epoch': 7.0}
# {'loss': 0.0807, 'grad_norm': 0.8361184597015381, 'learning_rate': 1.5234375000000001e-05, 'epoch': 8.0}
# {'eval_loss': 0.3135541081428528, 'eval_typed_precision': 0.4936530324400564, 'eval_typed_recall': 0.41866028708133973, 'eval_typed_f1': 0.453074433656958, 'eval_boundary_precision': 0.6581196581196581, 'eval_boundary_recall': 0.5526315789473685, 'eval_boundary_f1': 0.6007802340702211, 'eval_combined_f1': 0.5269273338635896, 'eval_runtime': 3.4405, 'eval_samples_per_second': 293.271, 'eval_steps_per_second': 9.301, 'epoch': 8.0}
# {'loss': 0.065, 'grad_norm': 1.1326597929000854, 'learning_rate': 1.0156250000000001e-05, 'epoch': 9.0}
# {'eval_loss': 0.3184302747249603, 'eval_typed_precision': 0.4922425952045134, 'eval_typed_recall': 0.41746411483253587, 'eval_typed_f1': 0.4517799352750809, 'eval_boundary_precision': 0.6552706552706553, 'eval_boundary_recall': 0.5502392344497608, 'eval_boundary_f1': 0.5981794538361508, 'eval_combined_f1': 0.5249796945556159, 'eval_runtime': 3.7159, 'eval_samples_per_second': 271.534, 'eval_steps_per_second': 8.612, 'epoch': 9.0}
# {'train_runtime': 121.3153, 'train_samples_per_second': 9.067, 'train_steps_per_second': 1.179, 'train_loss': 0.42438770563174516, 'epoch': 9.0}
# {'eval_loss': 0.3079485595226288, 'eval_typed_precision': 0.49239280774550487, 'eval_typed_recall': 0.4258373205741627, 'eval_typed_f1': 0.4567030147530468, 'eval_boundary_precision': 0.6518105849582173, 'eval_boundary_recall': 0.5598086124401914, 'eval_boundary_f1': 0.6023166023166023, 'eval_combined_f1': 0.5295098085348245, 'eval_runtime': 3.6671, 'eval_samples_per_second': 275.148, 'eval_steps_per_second': 8.726, 'epoch': 9.0}
# {'test_loss': 0.3299347162246704, 'test_typed_precision': 0.36503362151777136, 'test_typed_recall': 0.35217794253938833, 'test_typed_f1': 0.3584905660377358, 'test_boundary_precision': 0.539651837524178, 'test_boundary_recall': 0.5171455050973123, 'test_boundary_f1': 0.5281590156176053, 'test_combined_f1': 0.4433247908276705, 'test_runtime': 7.604, 'test_samples_per_second': 169.254, 'test_steps_per_second': 5.392, 'epoch': 9.0}
#
# Test results (mitigated):
#   Typed F1:    0.3585
#   Boundary F1: 0.5282
# Saved progress to: /content/drive/MyDrive/AAI590/data/processed/results/mitigated_retuned/mitigated_results.csv
# ================================================================================
# [MITIGATED] Dataset=wnut17 | Budget=100 | Seed=42
# ================================================================================
# {'loss': 2.0493, 'grad_norm': 13.73947525024414, 'learning_rate': 0.0, 'epoch': 1.0}
# {'train_runtime': 0.535, 'train_samples_per_second': 186.909, 'train_steps_per_second': 24.298, 'train_loss': 2.049322568453275, 'epoch': 1.0}
# {'loss': 1.4122, 'grad_norm': 5.807672500610352, 'learning_rate': 4.3333333333333334e-05, 'epoch': 1.0}
# {'eval_loss': 0.41832512617111206, 'eval_typed_precision': 0.33067729083665337, 'eval_typed_recall': 0.09928229665071771, 'eval_typed_f1': 0.15271389144434222, 'eval_boundary_precision': 0.5303643724696356, 'eval_boundary_recall': 0.15669856459330145, 'eval_boundary_f1': 0.2419205909510619, 'eval_combined_f1': 0.19731724119770205, 'eval_runtime': 3.4402, 'eval_samples_per_second': 293.293, 'eval_steps_per_second': 9.302, 'epoch': 1.0}
# {'loss': 0.3506, 'grad_norm': 3.417694568634033, 'learning_rate': 4.5703125e-05, 'epoch': 2.0}
# {'eval_loss': 0.2939232289791107, 'eval_typed_precision': 0.44, 'eval_typed_recall': 0.32894736842105265, 'eval_typed_f1': 0.37645448323066394, 'eval_boundary_precision': 0.55, 'eval_boundary_recall': 0.40789473684210525, 'eval_boundary_f1': 0.46840659340659335, 'eval_combined_f1': 0.42243053831862865, 'eval_runtime': 3.5093, 'eval_samples_per_second': 287.521, 'eval_steps_per_second': 9.119, 'epoch': 2.0}
# {'loss': 0.2441, 'grad_norm': 1.8396579027175903, 'learning_rate': 4.0625000000000005e-05, 'epoch': 3.0}
# {'eval_loss': 0.2817119061946869, 'eval_typed_precision': 0.48792270531400966, 'eval_typed_recall': 0.3624401913875598, 'eval_typed_f1': 0.4159231297185998, 'eval_boundary_precision': 0.5638126009693053, 'eval_boundary_recall': 0.41746411483253587, 'eval_boundary_f1': 0.47972508591065294, 'eval_combined_f1': 0.44782410781462634, 'eval_runtime': 3.407, 'eval_samples_per_second': 296.154, 'eval_steps_per_second': 9.392, 'epoch': 3.0}
# {'loss': 0.1722, 'grad_norm': 1.5815280675888062, 'learning_rate': 3.5546875e-05, 'epoch': 4.0}
# {'eval_loss': 0.27044612169265747, 'eval_typed_precision': 0.48493543758967, 'eval_typed_recall': 0.4043062200956938, 'eval_typed_f1': 0.4409654272667971, 'eval_boundary_precision': 0.5965417867435159, 'eval_boundary_recall': 0.49521531100478466, 'eval_boundary_f1': 0.5411764705882354, 'eval_combined_f1': 0.49107094892751624, 'eval_runtime': 3.5118, 'eval_samples_per_second': 287.319, 'eval_steps_per_second': 9.112, 'epoch': 4.0}
# {'loss': 0.1204, 'grad_norm': 5.387857913970947, 'learning_rate': 3.0468750000000002e-05, 'epoch': 5.0}
# {'eval_loss': 0.29058903455734253, 'eval_typed_precision': 0.45554035567715456, 'eval_typed_recall': 0.39832535885167464, 'eval_typed_f1': 0.4250159540523293, 'eval_boundary_precision': 0.5867768595041323, 'eval_boundary_recall': 0.5095693779904307, 'eval_boundary_f1': 0.5454545454545455, 'eval_combined_f1': 0.4852352497534374, 'eval_runtime': 3.6227, 'eval_samples_per_second': 278.52, 'eval_steps_per_second': 8.833, 'epoch': 5.0}
# {'loss': 0.0939, 'grad_norm': 0.5904582142829895, 'learning_rate': 2.5390625000000002e-05, 'epoch': 6.0}
# {'eval_loss': 0.2911621630191803, 'eval_typed_precision': 0.4606141522029373, 'eval_typed_recall': 0.4126794258373206, 'eval_typed_f1': 0.4353312302839117, 'eval_boundary_precision': 0.5908479138627187, 'eval_boundary_recall': 0.5251196172248804, 'eval_boundary_f1': 0.5560481317289424, 'eval_combined_f1': 0.4956896810064271, 'eval_runtime': 3.5468, 'eval_samples_per_second': 284.479, 'eval_steps_per_second': 9.022, 'epoch': 6.0}
# {'loss': 0.078, 'grad_norm': 3.321910858154297, 'learning_rate': 2.0312500000000002e-05, 'epoch': 7.0}
# {'eval_loss': 0.291012704372406, 'eval_typed_precision': 0.469910371318822, 'eval_typed_recall': 0.43899521531100477, 'eval_typed_f1': 0.45392702535559676, 'eval_boundary_precision': 0.5868725868725869, 'eval_boundary_recall': 0.5454545454545454, 'eval_boundary_f1': 0.5654060756354617, 'eval_combined_f1': 0.5096665504955292, 'eval_runtime': 3.4808, 'eval_samples_per_second': 289.873, 'eval_steps_per_second': 9.193, 'epoch': 7.0}
# {'loss': 0.0587, 'grad_norm': 0.9747642874717712, 'learning_rate': 1.5234375000000001e-05, 'epoch': 8.0}
# {'eval_loss': 0.2964170575141907, 'eval_typed_precision': 0.47006369426751593, 'eval_typed_recall': 0.44138755980861244, 'eval_typed_f1': 0.4552745219000617, 'eval_boundary_precision': 0.6056701030927835, 'eval_boundary_recall': 0.562200956937799, 'eval_boundary_f1': 0.5831265508684863, 'eval_combined_f1': 0.519200536384274, 'eval_runtime': 3.4735, 'eval_samples_per_second': 290.487, 'eval_steps_per_second': 9.213, 'epoch': 8.0}
# {'loss': 0.0541, 'grad_norm': 1.278755784034729, 'learning_rate': 1.0156250000000001e-05, 'epoch': 9.0}
# {'eval_loss': 0.3040043115615845, 'eval_typed_precision': 0.48433420365535246, 'eval_typed_recall': 0.4437799043062201, 'eval_typed_f1': 0.46317103620474404, 'eval_boundary_precision': 0.6169088507265522, 'eval_boundary_recall': 0.5586124401913876, 'eval_boundary_f1': 0.5863151286880101, 'eval_combined_f1': 0.524743082446377, 'eval_runtime': 3.5189, 'eval_samples_per_second': 286.739, 'eval_steps_per_second': 9.094, 'epoch': 9.0}
# {'loss': 0.0432, 'grad_norm': 0.3019985556602478, 'learning_rate': 5.078125000000001e-06, 'epoch': 10.0}
# {'eval_loss': 0.3061579167842865, 'eval_typed_precision': 0.4754521963824289, 'eval_typed_recall': 0.44019138755980863, 'eval_typed_f1': 0.45714285714285713, 'eval_boundary_precision': 0.6081258191349934, 'eval_boundary_recall': 0.5550239234449761, 'eval_boundary_f1': 0.5803627267041902, 'eval_combined_f1': 0.5187527919235236, 'eval_runtime': 3.5425, 'eval_samples_per_second': 284.828, 'eval_steps_per_second': 9.033, 'epoch': 10.0}
# {'loss': 0.0457, 'grad_norm': 0.881048321723938, 'learning_rate': 0.0, 'epoch': 11.0}
# {'eval_loss': 0.30698999762535095, 'eval_typed_precision': 0.47736093143596375, 'eval_typed_recall': 0.44138755980861244, 'eval_typed_f1': 0.4586699813548788, 'eval_boundary_precision': 0.610236220472441, 'eval_boundary_recall': 0.55622009569378, 'eval_boundary_f1': 0.5819774718397999, 'eval_combined_f1': 0.5203237265973393, 'eval_runtime': 3.7001, 'eval_samples_per_second': 272.698, 'eval_steps_per_second': 8.649, 'epoch': 11.0}
# {'train_runtime': 171.8069, 'train_samples_per_second': 6.403, 'train_steps_per_second': 0.832, 'train_loss': 0.24301756803806013, 'epoch': 11.0}
# {'eval_loss': 0.3040043115615845, 'eval_typed_precision': 0.48433420365535246, 'eval_typed_recall': 0.4437799043062201, 'eval_typed_f1': 0.46317103620474404, 'eval_boundary_precision': 0.6169088507265522, 'eval_boundary_recall': 0.5586124401913876, 'eval_boundary_f1': 0.5863151286880101, 'eval_combined_f1': 0.524743082446377, 'eval_runtime': 3.7019, 'eval_samples_per_second': 272.566, 'eval_steps_per_second': 8.644, 'epoch': 11.0}
# {'test_loss': 0.35248878598213196, 'test_typed_precision': 0.35789473684210527, 'test_typed_recall': 0.34661723818350326, 'test_typed_f1': 0.35216572504708094, 'test_boundary_precision': 0.5289017341040463, 'test_boundary_recall': 0.5088044485634847, 'test_boundary_f1': 0.5186584789796884, 'test_combined_f1': 0.43541210201338465, 'test_runtime': 7.6091, 'test_samples_per_second': 169.139, 'test_steps_per_second': 5.388, 'epoch': 11.0}
#
# Test results (mitigated):
#   Typed F1:    0.3522
#   Boundary F1: 0.5187
# Saved progress to: /content/drive/MyDrive/AAI590/data/processed/results/mitigated_retuned/mitigated_results.csv
# ================================================================================
# [MITIGATED] Dataset=wnut17 | Budget=100 | Seed=101
# ================================================================================
# {'loss': 2.5699, 'grad_norm': 17.37293815612793, 'learning_rate': 0.0, 'epoch': 1.0}
# {'train_runtime': 0.4697, 'train_samples_per_second': 212.904, 'train_steps_per_second': 27.678, 'train_loss': 2.5698761573204627, 'epoch': 1.0}
# {'loss': 1.7837, 'grad_norm': 8.757304191589355, 'learning_rate': 4.3333333333333334e-05, 'epoch': 1.0}
# {'eval_loss': 0.505983829498291, 'eval_typed_precision': 0.44630071599045346, 'eval_typed_recall': 0.2236842105263158, 'eval_typed_f1': 0.29800796812749003, 'eval_boundary_precision': 0.5815085158150851, 'eval_boundary_recall': 0.28588516746411485, 'eval_boundary_f1': 0.38331996792301526, 'eval_combined_f1': 0.3406639680252527, 'eval_runtime': 3.4909, 'eval_samples_per_second': 289.039, 'eval_steps_per_second': 9.167, 'epoch': 1.0}
# {'loss': 0.4042, 'grad_norm': 2.675960063934326, 'learning_rate': 4.5703125e-05, 'epoch': 2.0}
# {'eval_loss': 0.2963101267814636, 'eval_typed_precision': 0.3563348416289593, 'eval_typed_recall': 0.37679425837320574, 'eval_typed_f1': 0.3662790697674419, 'eval_boundary_precision': 0.45588235294117646, 'eval_boundary_recall': 0.4820574162679426, 'eval_boundary_f1': 0.46860465116279065, 'eval_combined_f1': 0.4174418604651163, 'eval_runtime': 3.3144, 'eval_samples_per_second': 304.429, 'eval_steps_per_second': 9.655, 'epoch': 2.0}
# {'loss': 0.2905, 'grad_norm': 3.3802976608276367, 'learning_rate': 4.0625000000000005e-05, 'epoch': 3.0}
# {'eval_loss': 0.2977699339389801, 'eval_typed_precision': 0.4535073409461664, 'eval_typed_recall': 0.33253588516746413, 'eval_typed_f1': 0.38371290545203596, 'eval_boundary_precision': 0.5383360522022839, 'eval_boundary_recall': 0.39473684210526316, 'eval_boundary_f1': 0.4554865424430642, 'eval_combined_f1': 0.4195997239475501, 'eval_runtime': 3.3953, 'eval_samples_per_second': 297.177, 'eval_steps_per_second': 9.425, 'epoch': 3.0}
# {'loss': 0.2017, 'grad_norm': 1.0132086277008057, 'learning_rate': 3.5546875e-05, 'epoch': 4.0}
# {'eval_loss': 0.277182936668396, 'eval_typed_precision': 0.3918757467144564, 'eval_typed_recall': 0.3923444976076555, 'eval_typed_f1': 0.39210998206814107, 'eval_boundary_precision': 0.49221556886227547, 'eval_boundary_recall': 0.4916267942583732, 'eval_boundary_f1': 0.4919210053859964, 'eval_combined_f1': 0.4420154937270687, 'eval_runtime': 3.6861, 'eval_samples_per_second': 273.732, 'eval_steps_per_second': 8.681, 'epoch': 4.0}
# {'loss': 0.1535, 'grad_norm': 0.9482918381690979, 'learning_rate': 3.0468750000000002e-05, 'epoch': 5.0}
# {'eval_loss': 0.2889575958251953, 'eval_typed_precision': 0.4351245085190039, 'eval_typed_recall': 0.39712918660287083, 'eval_typed_f1': 0.4152595372107567, 'eval_boundary_precision': 0.5610079575596817, 'eval_boundary_recall': 0.5059808612440191, 'eval_boundary_f1': 0.5320754716981133, 'eval_combined_f1': 0.473667504454435, 'eval_runtime': 3.6019, 'eval_samples_per_second': 280.128, 'eval_steps_per_second': 8.884, 'epoch': 5.0}
# {'loss': 0.1153, 'grad_norm': 0.7814696431159973, 'learning_rate': 2.5390625000000002e-05, 'epoch': 6.0}
# {'eval_loss': 0.29252493381500244, 'eval_typed_precision': 0.42769607843137253, 'eval_typed_recall': 0.41746411483253587, 'eval_typed_f1': 0.4225181598062954, 'eval_boundary_precision': 0.5576208178438662, 'eval_boundary_recall': 0.5382775119617225, 'eval_boundary_f1': 0.5477784540474742, 'eval_combined_f1': 0.4851483069268848, 'eval_runtime': 3.5845, 'eval_samples_per_second': 281.49, 'eval_steps_per_second': 8.927, 'epoch': 6.0}
# {'loss': 0.0943, 'grad_norm': 2.003396987915039, 'learning_rate': 2.0312500000000002e-05, 'epoch': 7.0}
# {'eval_loss': 0.2938551902770996, 'eval_typed_precision': 0.4635352286773795, 'eval_typed_recall': 0.4485645933014354, 'eval_typed_f1': 0.45592705167173253, 'eval_boundary_precision': 0.5844806007509387, 'eval_boundary_recall': 0.5586124401913876, 'eval_boundary_f1': 0.5712538226299694, 'eval_combined_f1': 0.513590437150851, 'eval_runtime': 3.4769, 'eval_samples_per_second': 290.198, 'eval_steps_per_second': 9.204, 'epoch': 7.0}
# {'loss': 0.0748, 'grad_norm': 1.0119390487670898, 'learning_rate': 1.5234375000000001e-05, 'epoch': 8.0}
# {'eval_loss': 0.3040294647216797, 'eval_typed_precision': 0.4909090909090909, 'eval_typed_recall': 0.45215311004784686, 'eval_typed_f1': 0.47073474470734744, 'eval_boundary_precision': 0.6226912928759895, 'eval_boundary_recall': 0.5645933014354066, 'eval_boundary_f1': 0.5922208281053951, 'eval_combined_f1': 0.5314777864063713, 'eval_runtime': 3.4524, 'eval_samples_per_second': 292.264, 'eval_steps_per_second': 9.269, 'epoch': 8.0}
# {'loss': 0.073, 'grad_norm': 0.7258913516998291, 'learning_rate': 1.0156250000000001e-05, 'epoch': 9.0}
# {'eval_loss': 0.3010576665401459, 'eval_typed_precision': 0.49049429657794674, 'eval_typed_recall': 0.46291866028708134, 'eval_typed_f1': 0.4763076923076923, 'eval_boundary_precision': 0.6224226804123711, 'eval_boundary_recall': 0.5777511961722488, 'eval_boundary_f1': 0.5992555831265509, 'eval_combined_f1': 0.5377816377171216, 'eval_runtime': 3.6477, 'eval_samples_per_second': 276.613, 'eval_steps_per_second': 8.773, 'epoch': 9.0}
# {'loss': 0.0583, 'grad_norm': 0.6071442365646362, 'learning_rate': 5.078125000000001e-06, 'epoch': 10.0}
# {'eval_loss': 0.3022010922431946, 'eval_typed_precision': 0.4905422446406053, 'eval_typed_recall': 0.465311004784689, 'eval_typed_f1': 0.47759361571516273, 'eval_boundary_precision': 0.6264441591784339, 'eval_boundary_recall': 0.583732057416268, 'eval_boundary_f1': 0.6043343653250774, 'eval_combined_f1': 0.5409639905201201, 'eval_runtime': 3.4537, 'eval_samples_per_second': 292.152, 'eval_steps_per_second': 9.265, 'epoch': 10.0}
# {'loss': 0.0542, 'grad_norm': 0.300338476896286, 'learning_rate': 0.0, 'epoch': 11.0}
# {'eval_loss': 0.30225324630737305, 'eval_typed_precision': 0.4905422446406053, 'eval_typed_recall': 0.465311004784689, 'eval_typed_f1': 0.47759361571516273, 'eval_boundary_precision': 0.6235595390524968, 'eval_boundary_recall': 0.5825358851674641, 'eval_boundary_f1': 0.6023500309214596, 'eval_combined_f1': 0.5399718233183112, 'eval_runtime': 3.568, 'eval_samples_per_second': 282.789, 'eval_steps_per_second': 8.969, 'epoch': 11.0}
# {'train_runtime': 159.6392, 'train_samples_per_second': 6.891, 'train_steps_per_second': 0.896, 'train_loss': 0.300321120065409, 'epoch': 11.0}
# {'eval_loss': 0.3022010922431946, 'eval_typed_precision': 0.4905422446406053, 'eval_typed_recall': 0.465311004784689, 'eval_typed_f1': 0.47759361571516273, 'eval_boundary_precision': 0.6264441591784339, 'eval_boundary_recall': 0.583732057416268, 'eval_boundary_f1': 0.6043343653250774, 'eval_combined_f1': 0.5409639905201201, 'eval_runtime': 3.7627, 'eval_samples_per_second': 268.162, 'eval_steps_per_second': 8.505, 'epoch': 11.0}
# {'test_loss': 0.3241754174232483, 'test_typed_precision': 0.4084761045987376, 'test_typed_recall': 0.4198331788693234, 'test_typed_f1': 0.4140767824497258, 'test_boundary_precision': 0.5673693858845096, 'test_boundary_recall': 0.5736793327154773, 'test_boundary_f1': 0.5705069124423964, 'test_combined_f1': 0.4922918474460611, 'test_runtime': 7.5987, 'test_samples_per_second': 169.37, 'test_steps_per_second': 5.396, 'epoch': 11.0}
#
# Test results (mitigated):
#   Typed F1:    0.4141
#   Boundary F1: 0.5705
# Saved progress to: /content/drive/MyDrive/AAI590/data/processed/results/mitigated_retuned/mitigated_results.csv
# ================================================================================
# [MITIGATED] Dataset=wnut17 | Budget=200 | Seed=13
# ================================================================================
# {'loss': 3.1102, 'grad_norm': 16.221277236938477, 'learning_rate': 0.0, 'epoch': 1.0}
# {'train_runtime': 0.9227, 'train_samples_per_second': 216.756, 'train_steps_per_second': 27.094, 'train_loss': 3.110159912109375, 'epoch': 1.0}
# {'loss': 1.4236, 'grad_norm': 1.7019555568695068, 'learning_rate': 4.777070063694268e-05, 'epoch': 1.0}
# {'eval_loss': 0.32881084084510803, 'eval_typed_precision': 0.40418679549114334, 'eval_typed_recall': 0.30023923444976075, 'eval_typed_f1': 0.34454358270418667, 'eval_boundary_precision': 0.5281803542673108, 'eval_boundary_recall': 0.3923444976076555, 'eval_boundary_f1': 0.45024021962937544, 'eval_combined_f1': 0.397391901166781, 'eval_runtime': 3.4599, 'eval_samples_per_second': 291.628, 'eval_steps_per_second': 9.249, 'epoch': 1.0}
# {'loss': 0.2914, 'grad_norm': 1.4087836742401123, 'learning_rate': 3.9808917197452234e-05, 'epoch': 2.0}
# {'eval_loss': 0.28507915139198303, 'eval_typed_precision': 0.43415906127770537, 'eval_typed_recall': 0.39832535885167464, 'eval_typed_f1': 0.4154709918902059, 'eval_boundary_precision': 0.5136897001303781, 'eval_boundary_recall': 0.47129186602870815, 'eval_boundary_f1': 0.49157829070492826, 'eval_combined_f1': 0.4535246412975671, 'eval_runtime': 3.3691, 'eval_samples_per_second': 299.486, 'eval_steps_per_second': 9.498, 'epoch': 2.0}
# {'loss': 0.203, 'grad_norm': 0.6014310717582703, 'learning_rate': 3.184713375796178e-05, 'epoch': 3.0}
# {'eval_loss': 0.28347113728523254, 'eval_typed_precision': 0.4588957055214724, 'eval_typed_recall': 0.4473684210526316, 'eval_typed_f1': 0.45305875227135073, 'eval_boundary_precision': 0.5796019900497512, 'eval_boundary_recall': 0.5574162679425837, 'eval_boundary_f1': 0.5682926829268293, 'eval_combined_f1': 0.51067571759909, 'eval_runtime': 3.6525, 'eval_samples_per_second': 276.248, 'eval_steps_per_second': 8.761, 'epoch': 3.0}
# {'loss': 0.1492, 'grad_norm': 1.7330586910247803, 'learning_rate': 2.388535031847134e-05, 'epoch': 4.0}
# {'eval_loss': 0.2905042767524719, 'eval_typed_precision': 0.45690672963400236, 'eval_typed_recall': 0.46291866028708134, 'eval_typed_f1': 0.45989304812834225, 'eval_boundary_precision': 0.5890083632019116, 'eval_boundary_recall': 0.5897129186602871, 'eval_boundary_f1': 0.5893604303646144, 'eval_combined_f1': 0.5246267392464783, 'eval_runtime': 3.5953, 'eval_samples_per_second': 280.641, 'eval_steps_per_second': 8.9, 'epoch': 4.0}
# {'loss': 0.1143, 'grad_norm': 0.7329773902893066, 'learning_rate': 1.592356687898089e-05, 'epoch': 5.0}
# {'eval_loss': 0.2958884537220001, 'eval_typed_precision': 0.4773561811505508, 'eval_typed_recall': 0.4665071770334928, 'eval_typed_f1': 0.4718693284936479, 'eval_boundary_precision': 0.6022304832713755, 'eval_boundary_recall': 0.5813397129186603, 'eval_boundary_f1': 0.5916007303712721, 'eval_combined_f1': 0.53173502943246, 'eval_runtime': 3.9047, 'eval_samples_per_second': 258.41, 'eval_steps_per_second': 8.195, 'epoch': 5.0}
# {'loss': 0.09, 'grad_norm': 1.1377729177474976, 'learning_rate': 7.961783439490445e-06, 'epoch': 6.0}
# {'eval_loss': 0.3018553853034973, 'eval_typed_precision': 0.4795673076923077, 'eval_typed_recall': 0.4772727272727273, 'eval_typed_f1': 0.4784172661870504, 'eval_boundary_precision': 0.6119221411192214, 'eval_boundary_recall': 0.6016746411483254, 'eval_boundary_f1': 0.6067551266586249, 'eval_combined_f1': 0.5425861964228376, 'eval_runtime': 3.4593, 'eval_samples_per_second': 291.679, 'eval_steps_per_second': 9.25, 'epoch': 6.0}
# {'loss': 0.0823, 'grad_norm': 1.181810975074768, 'learning_rate': 0.0, 'epoch': 7.0}
# {'eval_loss': 0.3018440008163452, 'eval_typed_precision': 0.47613365155131265, 'eval_typed_recall': 0.4772727272727273, 'eval_typed_f1': 0.47670250896057353, 'eval_boundary_precision': 0.6157575757575757, 'eval_boundary_recall': 0.6076555023923444, 'eval_boundary_f1': 0.6116797110174593, 'eval_combined_f1': 0.5441911099890164, 'eval_runtime': 3.6862, 'eval_samples_per_second': 273.724, 'eval_steps_per_second': 8.681, 'epoch': 7.0}
# {'train_runtime': 116.5521, 'train_samples_per_second': 12.012, 'train_steps_per_second': 1.501, 'train_loss': 0.3362675040108817, 'epoch': 7.0}
# {'eval_loss': 0.3018440008163452, 'eval_typed_precision': 0.47613365155131265, 'eval_typed_recall': 0.4772727272727273, 'eval_typed_f1': 0.47670250896057353, 'eval_boundary_precision': 0.6157575757575757, 'eval_boundary_recall': 0.6076555023923444, 'eval_boundary_f1': 0.6116797110174593, 'eval_combined_f1': 0.5441911099890164, 'eval_runtime': 3.6897, 'eval_samples_per_second': 273.462, 'eval_steps_per_second': 8.673, 'epoch': 7.0}
# {'test_loss': 0.3316185772418976, 'test_typed_precision': 0.39269813000890474, 'test_typed_recall': 0.4087117701575533, 'test_typed_f1': 0.40054495912806537, 'test_boundary_precision': 0.5618789521228545, 'test_boundary_recall': 0.5764596848934198, 'test_boundary_f1': 0.5690759377859103, 'test_combined_f1': 0.48481044845698784, 'test_runtime': 7.6482, 'test_samples_per_second': 168.276, 'test_steps_per_second': 5.361, 'epoch': 7.0}
#
# Test results (mitigated):
#   Typed F1:    0.4005
#   Boundary F1: 0.5691
# Saved progress to: /content/drive/MyDrive/AAI590/data/processed/results/mitigated_retuned/mitigated_results.csv
# ================================================================================
# [MITIGATED] Dataset=wnut17 | Budget=200 | Seed=42
# ================================================================================
# {'loss': 1.9361, 'grad_norm': 13.044590950012207, 'learning_rate': 0.0, 'epoch': 1.0}
# {'train_runtime': 0.9349, 'train_samples_per_second': 213.921, 'train_steps_per_second': 26.74, 'train_loss': 1.9360609436035157, 'epoch': 1.0}
# {'loss': 0.8809, 'grad_norm': 1.9622596502304077, 'learning_rate': 4.777070063694268e-05, 'epoch': 1.0}
# {'eval_loss': 0.2973107695579529, 'eval_typed_precision': 0.4464579901153213, 'eval_typed_recall': 0.3241626794258373, 'eval_typed_f1': 0.37560637560637555, 'eval_boundary_precision': 0.5572139303482587, 'eval_boundary_recall': 0.4019138755980861, 'eval_boundary_f1': 0.46699096594857537, 'eval_combined_f1': 0.42129867077747546, 'eval_runtime': 3.6386, 'eval_samples_per_second': 277.302, 'eval_steps_per_second': 8.794, 'epoch': 1.0}
# {'loss': 0.2977, 'grad_norm': 1.640413522720337, 'learning_rate': 3.9808917197452234e-05, 'epoch': 2.0}
# {'eval_loss': 0.2566525936126709, 'eval_typed_precision': 0.49516129032258066, 'eval_typed_recall': 0.3672248803827751, 'eval_typed_f1': 0.4217032967032967, 'eval_boundary_precision': 0.5776699029126213, 'eval_boundary_recall': 0.4270334928229665, 'eval_boundary_f1': 0.4910591471801926, 'eval_combined_f1': 0.4563812219417447, 'eval_runtime': 3.498, 'eval_samples_per_second': 288.447, 'eval_steps_per_second': 9.148, 'epoch': 2.0}
# {'loss': 0.1945, 'grad_norm': 1.375392198562622, 'learning_rate': 3.184713375796178e-05, 'epoch': 3.0}
# {'eval_loss': 0.2709234058856964, 'eval_typed_precision': 0.5410852713178295, 'eval_typed_recall': 0.41746411483253587, 'eval_typed_f1': 0.47130317353139767, 'eval_boundary_precision': 0.6635514018691588, 'eval_boundary_recall': 0.5095693779904307, 'eval_boundary_f1': 0.5764546684709067, 'eval_combined_f1': 0.5238789210011522, 'eval_runtime': 3.4451, 'eval_samples_per_second': 292.88, 'eval_steps_per_second': 9.289, 'epoch': 3.0}
# {'loss': 0.1395, 'grad_norm': 1.2862950563430786, 'learning_rate': 2.388535031847134e-05, 'epoch': 4.0}
# {'eval_loss': 0.2689976692199707, 'eval_typed_precision': 0.5128900949796472, 'eval_typed_recall': 0.45215311004784686, 'eval_typed_f1': 0.480610298792117, 'eval_boundary_precision': 0.6476190476190476, 'eval_boundary_recall': 0.569377990430622, 'eval_boundary_f1': 0.6059834500318269, 'eval_combined_f1': 0.5432968744119719, 'eval_runtime': 3.5164, 'eval_samples_per_second': 286.943, 'eval_steps_per_second': 9.1, 'epoch': 4.0}
# {'loss': 0.1028, 'grad_norm': 0.8236969113349915, 'learning_rate': 1.592356687898089e-05, 'epoch': 5.0}
# ...
# {'loss': 0.2467, 'grad_norm': 2.2851855754852295, 'learning_rate': 0.0, 'epoch': 7.0}
# {'eval_loss': 0.6850702166557312, 'eval_typed_precision': 0.36429308565531476, 'eval_typed_recall': 0.4352651048088779, 'eval_typed_f1': 0.3966292134831461, 'eval_boundary_precision': 0.6056166056166056, 'eval_boundary_recall': 0.6115906288532675, 'eval_boundary_f1': 0.6085889570552148, 'eval_combined_f1': 0.5026090852691805, 'eval_runtime': 1.3349, 'eval_samples_per_second': 206.005, 'eval_steps_per_second': 6.742, 'epoch': 7.0}
# {'train_runtime': 107.9039, 'train_samples_per_second': 12.975, 'train_steps_per_second': 1.622, 'train_loss': 0.5631355203901018, 'epoch': 7.0}
# {'eval_loss': 0.6850702166557312, 'eval_typed_precision': 0.36429308565531476, 'eval_typed_recall': 0.4352651048088779, 'eval_typed_f1': 0.3966292134831461, 'eval_boundary_precision': 0.6056166056166056, 'eval_boundary_recall': 0.6115906288532675, 'eval_boundary_f1': 0.6085889570552148, 'eval_combined_f1': 0.5026090852691805, 'eval_runtime': 1.3351, 'eval_samples_per_second': 205.984, 'eval_steps_per_second': 6.741, 'epoch': 7.0}
# {'test_loss': 0.6341687440872192, 'test_typed_precision': 0.3185542168674699, 'test_typed_recall': 0.3927510398098633, 'test_typed_f1': 0.3517828632251197, 'test_boundary_precision': 0.5993051534452808, 'test_boundary_recall': 0.6153388822829964, 'test_boundary_f1': 0.6072161924317981, 'test_combined_f1': 0.47949952782845895, 'test_runtime': 2.6506, 'test_samples_per_second': 207.877, 'test_steps_per_second': 6.791, 'epoch': 7.0}
#
# Test results (mitigated):
#   Typed F1:    0.3518
#   Boundary F1: 0.6072
# Saved progress to: /content/drive/MyDrive/AAI590/data/processed/results/mitigated_retuned/mitigated_results.csv
# ================================================================================
# [MITIGATED] Dataset=scierc | Budget=200 | Seed=101
# ================================================================================
# {'loss': 2.5345, 'grad_norm': 14.504161834716797, 'learning_rate': 0.0, 'epoch': 1.0}
# {'train_runtime': 0.8751, 'train_samples_per_second': 228.549, 'train_steps_per_second': 28.569, 'train_loss': 2.5345155334472658, 'epoch': 1.0}
# {'loss': 1.5048, 'grad_norm': 4.319616317749023, 'learning_rate': 4.777070063694268e-05, 'epoch': 1.0}
# {'eval_loss': 0.9642404913902283, 'eval_typed_precision': 0.023255813953488372, 'eval_typed_recall': 0.01726263871763255, 'eval_typed_f1': 0.019815994338287332, 'eval_boundary_precision': 0.10412926391382406, 'eval_boundary_recall': 0.07151664611590629, 'eval_boundary_f1': 0.08479532163742691, 'eval_combined_f1': 0.05230565798785712, 'eval_runtime': 1.3241, 'eval_samples_per_second': 207.692, 'eval_steps_per_second': 6.797, 'epoch': 1.0}
# {'loss': 0.8066, 'grad_norm': 3.1886372566223145, 'learning_rate': 3.9808917197452234e-05, 'epoch': 2.0}
# {'eval_loss': 0.8615447282791138, 'eval_typed_precision': 0.10355987055016182, 'eval_typed_recall': 0.07891491985203453, 'eval_typed_f1': 0.08957312806158153, 'eval_boundary_precision': 0.3771551724137931, 'eval_boundary_recall': 0.2157829839704069, 'eval_boundary_f1': 0.27450980392156865, 'eval_combined_f1': 0.18204146599157509, 'eval_runtime': 1.2993, 'eval_samples_per_second': 211.654, 'eval_steps_per_second': 6.927, 'epoch': 2.0}
# {'loss': 0.6176, 'grad_norm': 2.6088621616363525, 'learning_rate': 3.184713375796178e-05, 'epoch': 3.0}
# {'eval_loss': 0.7223839163780212, 'eval_typed_precision': 0.20951509606587373, 'eval_typed_recall': 0.28236744759556104, 'eval_typed_f1': 0.24054621848739494, 'eval_boundary_precision': 0.5603557814485387, 'eval_boundary_recall': 0.5437731196054254, 'eval_boundary_f1': 0.5519399249061326, 'eval_combined_f1': 0.39624307169676376, 'eval_runtime': 1.316, 'eval_samples_per_second': 208.974, 'eval_steps_per_second': 6.839, 'epoch': 3.0}
# {'loss': 0.4797, 'grad_norm': 2.39583420753479, 'learning_rate': 2.388535031847134e-05, 'epoch': 4.0}
# {'eval_loss': 0.6759999990463257, 'eval_typed_precision': 0.3050672182006205, 'eval_typed_recall': 0.3637484586929716, 'eval_typed_f1': 0.33183352080989875, 'eval_boundary_precision': 0.6066225165562914, 'eval_boundary_recall': 0.5647348951911221, 'eval_boundary_f1': 0.5849297573435505, 'eval_combined_f1': 0.4583816390767246, 'eval_runtime': 1.4269, 'eval_samples_per_second': 192.72, 'eval_steps_per_second': 6.307, 'epoch': 4.0}
# {'loss': 0.3728, 'grad_norm': 2.3407559394836426, 'learning_rate': 1.592356687898089e-05, 'epoch': 5.0}
# {'eval_loss': 0.6425527334213257, 'eval_typed_precision': 0.34685598377281945, 'eval_typed_recall': 0.4217016029593095, 'eval_typed_f1': 0.3806343906510852, 'eval_boundary_precision': 0.6348600508905853, 'eval_boundary_recall': 0.6152897657213316, 'eval_boundary_f1': 0.6249217282404509, 'eval_combined_f1': 0.502778059445768, 'eval_runtime': 1.3735, 'eval_samples_per_second': 200.215, 'eval_steps_per_second': 6.552, 'epoch': 5.0}
# {'loss': 0.3065, 'grad_norm': 2.028949737548828, 'learning_rate': 7.961783439490445e-06, 'epoch': 6.0}
# {'eval_loss': 0.6687182188034058, 'eval_typed_precision': 0.36619718309859156, 'eval_typed_recall': 0.41676942046855736, 'eval_typed_f1': 0.38985005767012687, 'eval_boundary_precision': 0.6373193166885677, 'eval_boundary_recall': 0.5980271270036991, 'eval_boundary_f1': 0.6170483460559796, 'eval_combined_f1': 0.5034492018630532, 'eval_runtime': 1.3864, 'eval_samples_per_second': 198.356, 'eval_steps_per_second': 6.492, 'epoch': 6.0}
# {'loss': 0.2687, 'grad_norm': 3.8410587310791016, 'learning_rate': 0.0, 'epoch': 7.0}
# {'eval_loss': 0.6453947424888611, 'eval_typed_precision': 0.371900826446281, 'eval_typed_recall': 0.4438964241676942, 'eval_typed_f1': 0.4047217537942664, 'eval_boundary_precision': 0.6489226869455006, 'eval_boundary_recall': 0.6313193588162762, 'eval_boundary_f1': 0.64, 'eval_combined_f1': 0.5223608768971332, 'eval_runtime': 1.4607, 'eval_samples_per_second': 188.268, 'eval_steps_per_second': 6.162, 'epoch': 7.0}
# {'train_runtime': 89.4898, 'train_samples_per_second': 15.644, 'train_steps_per_second': 1.956, 'train_loss': 0.6223796680995396, 'epoch': 7.0}
# {'eval_loss': 0.6453947424888611, 'eval_typed_precision': 0.371900826446281, 'eval_typed_recall': 0.4438964241676942, 'eval_typed_f1': 0.4047217537942664, 'eval_boundary_precision': 0.6489226869455006, 'eval_boundary_recall': 0.6313193588162762, 'eval_boundary_f1': 0.64, 'eval_combined_f1': 0.5223608768971332, 'eval_runtime': 1.343, 'eval_samples_per_second': 204.764, 'eval_steps_per_second': 6.701, 'epoch': 7.0}
# {'test_loss': 0.6032025814056396, 'test_typed_precision': 0.34416243654822337, 'test_typed_recall': 0.4028520499108734, 'test_typed_f1': 0.3712017519846701, 'test_boundary_precision': 0.6229705351773902, 'test_boundary_recall': 0.6159334126040428, 'test_boundary_f1': 0.6194319880418534, 'test_combined_f1': 0.49531687001326175, 'test_runtime': 2.6731, 'test_samples_per_second': 206.127, 'test_steps_per_second': 6.734, 'epoch': 7.0}
#
# Test results (mitigated):
#   Typed F1:    0.3712
#   Boundary F1: 0.6194
# Saved progress to: /content/drive/MyDrive/AAI590/data/processed/results/mitigated_retuned/mitigated_results.csv
#    dataset  budget  seed  num_train_sentences  num_epochs  \
# 0   scierc      50    13                   50          10
# 1   scierc      50    42                   50          10
# 2   scierc      50   101                   50          10
# 3   scierc     100    13                  100          12
# 4   scierc     100    42                  100          12
# 5   scierc     100   101                  100          12
# 6   scierc     200    13                  200           8
# 7   scierc     200    42                  200           8
# 8   scierc     200   101                  200           8
# 9   wnut17      50    13                   50          10
# 10  wnut17      50    42                   50          10
# 11  wnut17      50   101                   50          10
# 12  wnut17     100    13                  100          12
# 13  wnut17     100    42                  100          12
# 14  wnut17     100   101                  100          12
# 15  wnut17     200    13                  200           8
# 16  wnut17     200    42                  200           8
# 17  wnut17     200   101                  200           8
#
#                                       best_checkpoint  best_validation_metric  \
# 0   /content/mitigated_checkpoints/scierc_budget50...                0.041108
# 1   /content/mitigated_checkpoints/scierc_budget50...                0.333600
# 2   /content/mitigated_checkpoints/scierc_budget50...                0.277774
# 3   /content/mitigated_checkpoints/scierc_budget10...                0.429707
# 4   /content/mitigated_checkpoints/scierc_budget10...                0.438731
# 5   /content/mitigated_checkpoints/scierc_budget10...                0.427962
# 6   /content/mitigated_checkpoints/scierc_budget20...                0.493198
# 7   /content/mitigated_checkpoints/scierc_budget20...                0.502609
# 8   /content/mitigated_checkpoints/scierc_budget20...                0.522361
# 9   /content/mitigated_checkpoints/wnut17_budget50...                0.472809
# 10  /content/mitigated_checkpoints/wnut17_budget50...                0.419996
# 11  /content/mitigated_checkpoints/wnut17_budget50...                0.431201
# 12  /content/mitigated_checkpoints/wnut17_budget10...                0.529510
# 13  /content/mitigated_checkpoints/wnut17_budget10...                0.524743
# 14  /content/mitigated_checkpoints/wnut17_budget10...                0.540964
# 15  /content/mitigated_checkpoints/wnut17_budget20...                0.544191
# 16  /content/mitigated_checkpoints/wnut17_budget20...                0.559807
# 17  /content/mitigated_checkpoints/wnut17_budget20...                0.568086
#
#     training_loss  validation_typed_f1  validation_boundary_f1  ...  \
# 0        1.717239             0.014315                0.067901  ...
# 1        0.771513             0.198881                0.468320  ...
# 2        0.948140             0.134884                0.420664  ...
# 3        0.663400             0.304740                0.554673  ...
# 4        0.734748             0.271186                0.606276  ...
# 5        0.628097             0.292544                0.563380  ...
# 6        0.655321             0.373211                0.613184  ...
# 7        0.563136             0.396629                0.608589  ...
# 8        0.622380             0.404722                0.640000  ...
# 9        0.591479             0.419934                0.525684  ...
# 10       0.482947             0.377287                0.462705  ...
# 11       0.482982             0.384010                0.478393  ...
# 12       0.424388             0.456703                0.602317  ...
# 13       0.243018             0.463171                0.586315  ...
# 14       0.300321             0.477594                0.604334  ...
# 15       0.336268             0.476703                0.611680  ...
# 16       0.253535             0.499679                0.619936  ...
# 17       0.290538             0.499697                0.636475  ...
#
#     test_typed_precision  test_typed_recall  test_typed_f1  \
# 0               0.034091           0.007130       0.011794
# 1               0.156886           0.160428       0.158637
# 2               0.124870           0.142602       0.133148
# 3               0.257267           0.315508       0.283427
# 4               0.233347           0.335116       0.275122
# 5               0.270353           0.313725       0.290429
# 6               0.335543           0.390969       0.361142
# 7               0.318554           0.392751       0.351783
# 8               0.344162           0.402852       0.371202
# 9               0.365532           0.308619       0.334673
# 10              0.296025           0.262280       0.278133
# 11              0.292419           0.300278       0.296296
# 12              0.365034           0.352178       0.358491
# 13              0.357895           0.346617       0.352166
# 14              0.408476           0.419833       0.414077
# 15              0.392698           0.408712       0.400545
# 16              0.399408           0.375348       0.387004
# 17              0.391489           0.426321       0.408163
#
#     test_boundary_precision  test_boundary_recall  test_boundary_f1  \
# 0                  0.184971              0.038050          0.063116
# 1                  0.525386              0.424495          0.469582
# 2                  0.424900              0.442331          0.433440
# 3                  0.535117              0.570749          0.552359
# 4                  0.575823              0.634364          0.603678
# 5                  0.593750              0.553508          0.572923
# 6                  0.608180              0.609988          0.609083
# 7                  0.599305              0.615339          0.607216
# 8                  0.622971              0.615933          0.619432
# 9                  0.517660              0.434662          0.472544
# 10                 0.458639              0.405931          0.430678
# 11                 0.437273              0.445783          0.441487
# 12                 0.539652              0.517146          0.528159
# 13                 0.528902              0.508804          0.518658
# 14                 0.567369              0.573679          0.570507
# 15                 0.561879              0.576460          0.569076
# 16                 0.577800              0.540315          0.558429
# 17                 0.546401              0.583874          0.564516
#
#     test_combined_f1  train_seconds  \
# 0           0.037455           39.4
# 1           0.314110          104.5
# 2           0.283294           83.2
# 3           0.417893          130.9
# 4           0.439400           71.3
# 5           0.431676          117.1
# 6           0.485112           99.2
# 7           0.479500          109.7
# 8           0.495317           91.5
# 9           0.403609          149.4
# 10          0.354406           91.4
# 11          0.368892          131.9
# 12          0.443325          123.2
# 13          0.435412          173.6
# 14          0.492292          161.3
# 15          0.484810          118.5
# 16          0.472717          113.5
# 17          0.486340          108.7
#
#                                              per_type saved_model_path
# 0   {"Generic": {"precision": 0.0, "recall": 0.0, ...             None
# 1   {"Generic": {"precision": 1.0, "recall": 0.016...             None
# 2   {"Generic": {"precision": 0.0, "recall": 0.0, ...             None
# 3   {"Generic": {"precision": 0.5815217391304348, ...             None
# 4   {"Generic": {"precision": 0.75, "recall": 0.32...             None
# 5   {"Generic": {"precision": 0.625, "recall": 0.3...             None
# 6   {"Generic": {"precision": 0.6384180790960452, ...             None
# 7   {"Generic": {"precision": 0.6071428571428571, ...             None
# 8   {"Generic": {"precision": 0.6863905325443787, ...             None
# 9   {"corporation": {"precision": 0.1, "recall": 0...             None
# 10  {"corporation": {"precision": 0.0, "recall": 0...             None
# 11  {"corporation": {"precision": 0.19277108433734...             None
# 12  {"corporation": {"precision": 0.12121212121212...             None
# 13  {"corporation": {"precision": 0.10465116279069...             None
# 14  {"corporation": {"precision": 0.15315315315315...             None
# 15  {"corporation": {"precision": 0.13496932515337...             None
# 16  {"corporation": {"precision": 0.13636363636363...             None
# 17  {"corporation": {"precision": 0.13492063492063...             None
#
# [18 rows x 21 columns]

# %% [markdown]
# ## Step 7 — Aggregate results across seeds

# %%
metric_columns = [
    "test_typed_precision",
    "test_typed_recall",
    "test_typed_f1",
    "test_boundary_precision",
    "test_boundary_recall",
    "test_boundary_f1",
    "test_combined_f1",
]

summary_df = (
    results_df
    .groupby(["dataset", "budget"])[metric_columns]
    .agg(["mean", "std"])
    .reset_index()
)

summary_df.columns = [
    "_".join(str(part) for part in col if str(part))
    if isinstance(col, tuple) else col
    for col in summary_df.columns
]

summary_path = MITIGATED_RESULTS_DIR / "mitigated_summary_by_budget.csv"
summary_df.to_csv(summary_path, index=False)

display(summary_df.round(4))
print("Saved summary to:", summary_path)
# Out:
#   dataset  budget  test_typed_precision_mean  test_typed_precision_std  \
# 0  scierc      50                     0.1053                    0.0637
# 1  scierc     100                     0.2537                    0.0188
# 2  scierc     200                     0.3328                    0.0130
# 3  wnut17      50                     0.3180                    0.0412
# 4  wnut17     100                     0.3771                    0.0274
# 5  wnut17     200                     0.3945                    0.0043
#
#    test_typed_recall_mean  test_typed_recall_std  test_typed_f1_mean  \
# 0                  0.1034                 0.0838              0.1012
# 1                  0.3214                 0.0119              0.2830
# 2                  0.3955                 0.0064              0.3614
# 3                  0.2904                 0.0247              0.3030
# 4                  0.3729                 0.0408              0.3749
# 5                  0.4035                 0.0259              0.3986
#
#    test_typed_f1_std  test_boundary_precision_mean  \
# 0             0.0785                        0.3784
# 1             0.0077                        0.5682
# 2             0.0097                        0.6102
# 3             0.0289                        0.4712
# 4             0.0341                        0.5453
# 5             0.0107                        0.5620
#
#    test_boundary_precision_std  test_boundary_recall_mean  \
# 0                       0.1749                     0.3016
# 1                       0.0300                     0.5862
# 2                       0.0120                     0.6138
# 3                       0.0416                     0.4288
# 4                       0.0198                     0.5332
# 5                       0.0157                     0.5669
#
#    test_boundary_recall_std  test_boundary_f1_mean  test_boundary_f1_std  \
# 0                    0.2284                 0.3220                0.2250
# 1                    0.0426                 0.5763                0.0258
# 2                    0.0033                 0.6119                0.0066
# 3                    0.0206                 0.4482                0.0217
# 4                    0.0353                 0.5391                0.0276
# 5                    0.0233                 0.5640                0.0053
#
#    test_combined_f1_mean  test_combined_f1_std
# 0                 0.2116                0.1516
# 1                 0.4297                0.0109
# 2                 0.4866                0.0080
# 3                 0.3756                0.0253
# 4                 0.4570                0.0308
# 5                 0.4813                0.0075
# Saved summary to: /content/drive/MyDrive/AAI590/data/processed/results/mitigated_retuned/mitigated_summary_by_budget.csv

# %% [markdown]
# ## Step 8 — Three-way comparison: zero-shot vs. naive few-shot (NB05) vs. mitigated few-shot (NB06)

# %%
BASELINE_RESULTS_PATH = RESULTS_DIR / "baseline_results.json"
NAIVE_RESULTS_PATH = NAIVE_FEWSHOT_RESULTS_DIR / "fewshot_results.csv"

comparison_rows = []

# --- Zero-shot (Notebook 04) ---
if BASELINE_RESULTS_PATH.exists():
    with open(BASELINE_RESULTS_PATH) as f:
        baseline_results = json.load(f)
    zero_shot = baseline_results.get("zero_shot_cross_domain_boundary_f1", {})
    for dataset_name in TARGET_DATASETS:
        values = zero_shot.get(dataset_name)
        if values:
            comparison_rows.append({
                "dataset": dataset_name,
                "budget": 0,
                "method": "Zero-shot baseline",
                "boundary_f1_mean": values.get("f1"),
                "boundary_f1_std": 0.0,
            })
else:
    print("Notebook 04 baseline_results.json not found -- run Notebook 04 first.")

# --- Naive few-shot (Notebook 05) ---
if NAIVE_RESULTS_PATH.exists():
    naive_df = pd.read_csv(NAIVE_RESULTS_PATH)
    naive_boundary = (
        naive_df.groupby(["dataset", "budget"])["test_boundary_f1"]
        .agg(["mean", "std"]).reset_index()
    )
    for row in naive_boundary.itertuples():
        comparison_rows.append({
            "dataset": row.dataset,
            "budget": int(row.budget),
            "method": "Naive few-shot (NB05)",
            "boundary_f1_mean": row.mean,
            "boundary_f1_std": row.std,
        })
else:
    print("Notebook 05 fewshot_results.csv not found -- run Notebook 05 first for the full comparison.")

# --- Mitigated few-shot (this notebook) ---
mitigated_boundary = (
    results_df.groupby(["dataset", "budget"])["test_boundary_f1"]
    .agg(["mean", "std"]).reset_index()
)
for row in mitigated_boundary.itertuples():
    comparison_rows.append({
        "dataset": row.dataset,
        "budget": int(row.budget),
        "method": "Mitigated retuned (NB06b)",
        "boundary_f1_mean": row.mean,
        "boundary_f1_std": row.std,
    })

three_way_df = (
    pd.DataFrame(comparison_rows)
    .sort_values(["dataset", "budget", "method"])
    .reset_index(drop=True)
)

comparison_path = MITIGATED_RESULTS_DIR / "three_way_boundary_comparison.csv"
three_way_df.to_csv(comparison_path, index=False)

display(three_way_df.round(4))
print("Saved comparison to:", comparison_path)
# Out:
#    dataset  budget                     method  boundary_f1_mean  \
# 0   scierc       0         Zero-shot baseline            0.0684
# 1   scierc      50  Mitigated retuned (NB06b)            0.3220
# 2   scierc      50      Naive few-shot (NB05)            0.5309
# 3   scierc     100  Mitigated retuned (NB06b)            0.5763
# 4   scierc     100      Naive few-shot (NB05)            0.5721
# 5   scierc     200  Mitigated retuned (NB06b)            0.6119
# 6   scierc     200      Naive few-shot (NB05)            0.6241
# 7   wnut17       0         Zero-shot baseline            0.6095
# 8   wnut17      50  Mitigated retuned (NB06b)            0.4482
# 9   wnut17      50      Naive few-shot (NB05)            0.4474
# 10  wnut17     100  Mitigated retuned (NB06b)            0.5391
# 11  wnut17     100      Naive few-shot (NB05)            0.5413
# 12  wnut17     200  Mitigated retuned (NB06b)            0.5640
# 13  wnut17     200      Naive few-shot (NB05)            0.5653
#
#     boundary_f1_std
# 0            0.0000
# 1            0.2250
# 2            0.0239
# 3            0.0258
# 4            0.0161
# 5            0.0066
# 6            0.0041
# 7            0.0000
# 8            0.0217
# 9            0.0427
# 10           0.0276
# 11           0.0213
# 12           0.0053
# 13           0.0145
# Saved comparison to: /content/drive/MyDrive/AAI590/data/processed/results/mitigated_retuned/three_way_boundary_comparison.csv

# %% [markdown]
# ## Step 9 — Plot the three-way comparison

# %%
for dataset_name in TARGET_DATASETS:
    plt.figure(figsize=(7, 5))

    for method, group in three_way_df[three_way_df["dataset"] == dataset_name].groupby("method"):
        group = group.sort_values("budget")
        plt.errorbar(
            group["budget"],
            group["boundary_f1_mean"],
            yerr=group["boundary_f1_std"].fillna(0),
            marker="o",
            capsize=4,
            label=method,
        )

    plt.xlabel("Number of labeled target-domain sentences")
    plt.ylabel("Entity-boundary F1")
    plt.title(f"{dataset_name}: Zero-Shot vs. Naive vs. Mitigated Few-Shot")
    all_budgets = sorted(three_way_df.loc[three_way_df["dataset"] == dataset_name, "budget"].unique())
    plt.xticks(all_budgets)
    plt.ylim(0, 1)
    plt.grid(alpha=0.3)
    plt.legend()
    plt.tight_layout()

    output_path = MITIGATED_RESULTS_DIR / f"{dataset_name}_three_way_boundary_comparison.png"
    plt.savefig(output_path, dpi=200, bbox_inches="tight")
    plt.show()
    print("Saved:", output_path)
# Out:
# Saved: /content/drive/MyDrive/AAI590/data/processed/results/mitigated_retuned/wnut17_three_way_boundary_comparison.png
# Saved: /content/drive/MyDrive/AAI590/data/processed/results/mitigated_retuned/scierc_three_way_boundary_comparison.png

# %% [markdown]
# ## Step 10 — Presentation-ready results table

# %%
presentation_rows = []

for dataset_name in TARGET_DATASETS:
    for method in ["Zero-shot baseline", "Naive few-shot (NB05)", "Mitigated retuned (NB06b)"]:
        subset = three_way_df[
            (three_way_df["dataset"] == dataset_name) &
            (three_way_df["method"] == method)
        ].sort_values("budget")

        for row in subset.itertuples():
            presentation_rows.append({
                "Dataset": dataset_name,
                "Method": method,
                "Budget": row.budget,
                "Boundary F1": f"{row.boundary_f1_mean:.3f} ± {0 if pd.isna(row.boundary_f1_std) else row.boundary_f1_std:.3f}",
            })

presentation_df = pd.DataFrame(presentation_rows)
presentation_path = MITIGATED_RESULTS_DIR / "presentation_three_way_table.csv"
presentation_df.to_csv(presentation_path, index=False)

display(presentation_df)
print("Saved:", presentation_path)
# Out:
#    Dataset                     Method  Budget    Boundary F1
# 0   wnut17         Zero-shot baseline       0  0.610 ± 0.000
# 1   wnut17      Naive few-shot (NB05)      50  0.447 ± 0.043
# 2   wnut17      Naive few-shot (NB05)     100  0.541 ± 0.021
# 3   wnut17      Naive few-shot (NB05)     200  0.565 ± 0.014
# 4   wnut17  Mitigated retuned (NB06b)      50  0.448 ± 0.022
# 5   wnut17  Mitigated retuned (NB06b)     100  0.539 ± 0.028
# 6   wnut17  Mitigated retuned (NB06b)     200  0.564 ± 0.005
# 7   scierc         Zero-shot baseline       0  0.068 ± 0.000
# 8   scierc      Naive few-shot (NB05)      50  0.531 ± 0.024
# 9   scierc      Naive few-shot (NB05)     100  0.572 ± 0.016
# 10  scierc      Naive few-shot (NB05)     200  0.624 ± 0.004
# 11  scierc  Mitigated retuned (NB06b)      50  0.322 ± 0.225
# 12  scierc  Mitigated retuned (NB06b)     100  0.576 ± 0.026
# 13  scierc  Mitigated retuned (NB06b)     200  0.612 ± 0.007
# Saved: /content/drive/MyDrive/AAI590/data/processed/results/mitigated_retuned/presentation_three_way_table.csv

# %% [markdown]
# ## Step 11 — Final output inventory
#
# The main files produced by this notebook are:
#
# - `mitigated_results.csv` / `mitigated_results.json` — every individual mitigated run
# - `mitigated_summary_by_budget.csv` — mean and standard deviation across seeds
# - `three_way_boundary_comparison.csv` — zero-shot vs. naive (NB05) vs. mitigated (NB06)
# - `presentation_three_way_table.csv` — compact table for the final presentation
# - Three-way comparison plots for WNUT-17 and SciERC
#
# **How to read the result:** if the mitigated WNUT-17 curve now sits at or above the 0.610
# zero-shot line at budget 200 (and SciERC's gains from Notebook 05 are preserved), that
# confirms catastrophic forgetting — not few-shot adaptation itself — was the cause of the
# Notebook 05 regression, and this training recipe is the one worth carrying into the final
# report. If WNUT-17 still lags zero-shot even here, that points to the data (few-shot sampling
# skew from Notebook 02, or the inherent difficulty of WNUT-17's noisy/emerging entities) as the
# next thing to investigate, rather than the training procedure.

# %%
print("Notebook 06 outputs:")
for path in sorted(MITIGATED_RESULTS_DIR.glob("*")):
    print(" -", path.name)
# Out:
# Notebook 06 outputs:
#  - mitigated_results.csv
#  - mitigated_results.json
#  - mitigated_summary_by_budget.csv
#  - presentation_three_way_table.csv
#  - scierc_three_way_boundary_comparison.png
#  - three_way_boundary_comparison.csv
#  - wnut17_three_way_boundary_comparison.png
